# %% [markdown]
# ##### Loading libraries and data

# %%
# !pip install evaluate
# !pip install bert_score
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import torch
import pandas as pd
from time import time
from evaluate import load
import matplotlib.pyplot as plt
import tensorflow as tf
nltk.download("")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##### Importing data and necessary preprocessing

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !unzip "drive/MyDrive/Quora-QnA/quora-question-pairs" -d "quora-question-pairs"
# !unzip "quora-question-pairs/train.csv.zip"
# !unzip "quora-question-pairs/test.csv.zip"
# Out:
# Archive:  drive/MyDrive/Quora-QnA/quora-question-pairs.zip
#   inflating: quora-question-pairs/sample_submission.csv.zip
#   inflating: quora-question-pairs/test.csv
#   inflating: quora-question-pairs/test.csv.zip
#   inflating: quora-question-pairs/train.csv.zip
# Archive:  quora-question-pairs/train.csv.zip
#   inflating: train.csv
# Archive:  quora-question-pairs/test.csv.zip
#   inflating: test.csv

# %%
df = pd.read_csv("drive/MyDrive/Extramarks Project/Dataset versions/QQD-cleaner-less.csv")

# %% [markdown]
# ##### Calculating BERT Scores

# %%
bertscore = load("bertscore")

# %%
df = df.dropna()
df = df[df['question2'].str.len() >= 10]
df = df[df['question1'].str.len() >= 10]

# %% [markdown]
# GPU based execution for 10k samples ==> 2 m 42 s

# %%
# should print empty
for i in df['question1']:
  if type(i) != type("") or len(i) <= 7 :
    print(i)

# %%
t =time()
predictions1 = list(df[:40000]['question1'])
references1 = list(df[:40000]['question2'])
results1 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
print("Time taken: " , int((time() - t)%60) ,"s, ", int((time() - t)/60), "m")
# Out:
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1126 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -39410.11 seconds, -1.01 sentences/sec
# Time taken:  5 s,  5 m

# %%
predictions1 = list(df[40000:80000]['question1'])
references1 = list(df[40000:80000]['question2'])
results2 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1124 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -39160.93 seconds, -1.02 sentences/sec

# %%
predictions1 = list(df[80000:120000]['question1'])
references1 = list(df[80000:120000]['question2'])
results3 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1124 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -38957.92 seconds, -1.03 sentences/sec

# %%
predictions1 = list(df[120000:160000]['question1'])
references1 = list(df[120000:160000]['question2'])
results4 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1124 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -38754.98 seconds, -1.03 sentences/sec

# %%
predictions1 = list(df[160000:200000]['question1'])
references1 = list(df[160000:200000]['question2'])
results5 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1124 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -38551.78 seconds, -1.04 sentences/sec

# %%
predictions1 = list(df[200000:240000]['question1'])
references1 = list(df[200000:240000]['question2'])
results6 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1126 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -38286.17 seconds, -1.04 sentences/sec

# %%
predictions1 = list(df[240000:280000]['question1'])
references1 = list(df[240000:280000]['question2'])
results7 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1125 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -38084.14 seconds, -1.05 sentences/sec

# %%
predictions1 = list(df[280000:320000]['question1'])
references1 = list(df[280000:320000]['question2'])
results8 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1124 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -37870.88 seconds, -1.06 sentences/sec

# %%
predictions1 = list(df[320000:360000]['question1'])
references1 = list(df[320000:360000]['question2'])
results9 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1126 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -37666.85 seconds, -1.06 sentences/sec

# %%
predictions1 = list(df[360000:400000]['question1'])
references1 = list(df[360000:400000]['question2'])
results10 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1131 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/625 [00:00<?, ?it/s]
# done in -37462.13 seconds, -1.07 sentences/sec

# %%
predictions1 = list(df[400000:]['question1'])
references1 = list(df[400000:]['question2'])
results11 = bertscore.compute(predictions=predictions1, references=references1, lang="en", rescale_with_baseline=True, verbose = True)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/127 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/65 [00:00<?, ?it/s]
# done in -1566.25 seconds, -2.64 sentences/sec

# %%
resultFinalF1= results1['f1']+results2['f1']+results3['f1']+results4['f1']+results5['f1']+results6['f1']+results7['f1']+results8['f1']+results9['f1']+results10['f1']+results11['f1']
resultFinalRecall= results1['recall']+results2['recall']+results3['recall']+results4['recall']+results5['recall']+results6['recall']+results7['recall']+results8['recall']+results9['recall']+results10['recall']+results11['recall']
resultFinalPrecision= results1['precision']+results2['precision']+results3['precision']+results4['precision']+results5['precision']+results6['precision']+results7['precision']+results8['precision']+results9['precision']+results10['precision']+results11['precision']

# %%
len(resultFinalF1)
# Out:
# 404128

# %%
len(df)
# Out:
# 404128

# %% [markdown]
# ##### Saving results

# %%
df['bert-scores-precision'] = resultFinalF1
df['bert-scores-recall'] = resultFinalRecall
df['bert-scores-f1'] = resultFinalPrecision

# %%
df.to_csv("QQD-with-bert-scores.csv")
