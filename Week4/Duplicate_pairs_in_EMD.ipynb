# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkteshV/Question_duplicate_detection/blob/main/Week4/Duplicate_pairs_in_EMD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA on ExtraMarks Dataset (EMD)**

# %% [markdown]
# Dataset : https://drive.google.com/file/d/1Tk8RMvZr6cnwSRIBVnnsNe7z50SWbY_9/view?usp=sharing
#
# *Key features* about the data :
#
# 1. Unlabelled Data
#
# 2. There were many columns/features in the actual dataset though we have taken only two of them, 1st being the `question text` itself and second the `syllabus id` associated with it.
#
# 3. A rough idea on how syllabus id can be useful is , creating large buckets of questions of same subjects and then we kind of reduce our search space for near duplicates.
#
# 4. Though can't be sure if syllabus id are 100% correct or not (Human errors).
#
# 5. The question text has been preprocessed. Like removing some hyperlinks from the question, removing questions having many numerical data at this point of time.
# ---
#
# ###**AIM :**
# `Getting familiar with the EM Dataset and exploring it a bit more deeply`.

# %% [markdown]
# ### **Question data field**
#
# https://drive.google.com/file/d/1qOR1WOItaBvwOhihDJ4nFnqD8sgyYwr4/view?usp=sharing

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("drive/My Drive/Extramarks Project/Dataset versions/JEE-with-answers-without-numericals.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = df[['question_id','question','syllabus_id','answer','question_type']]
df
# Out:
#         question_id                                           question  \
# 0           2073346         How many π bonds are present in ferrocene
# 1           2073324  What is covalency of chlorine atom in second e...
# 2           2073225  In solid X atoms goes to corner of the cube an...
# 3           2073215  Calculate value of x y here x and y are the to...
# 4           2073202  In phosphorus acid if X is number of non bondi...
# ...             ...                                                ...
# 134426       420545  A dice is rolled thrice The probability of get...
# 134427       420544  A dice is rolled thrice The probability of get...
# 134428       420543                       subjective english question
# 134429       415580                       question subjective english
# 134430       415579                      subjective english questions
#
#        syllabus_id                                             answer  \
# 0           700295                                                 a
# 1           698013                                                 a
# 2           700078                         No of x atoms 8 18 2 12 2
# 3           697895  stryde images 2022 04 11 202204110162130016496...
# 4           697895  stryde images 2022 04 11 202204119693370016496...
# ...            ...                                                ...
# 134426          -1                                         frac 5 24
# 134427          -1                                         frac 5 24
# 134428          -1                                 answer_subjective
# 134429          -1                           answer subjective hindi
# 134430          -1                           answer of this question
#
#                  question_type
# 0          Subjective Question
# 1          Subjective Question
# 2          Subjective Question
# 3          Subjective Question
# 4          Subjective Question
# ...                        ...
# 134426  Single Choice Question
# 134427  Single Choice Question
# 134428     Subjective Question
# 134429     Subjective Question
# 134430     Subjective Question
#
# [134431 rows x 5 columns]

# %%
print("Number of Questions in this pre-processed data :", df.shape[0])
print(df.shape)
# Out:
# Number of Questions in this pre-processed data : 134431
# (134431, 5)

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134431 entries, 0 to 134430
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   question_id    134431 non-null  int64
#  1   question       134431 non-null  object
#  2   syllabus_id    134431 non-null  object
#  3   answer         133850 non-null  object
#  4   question_type  134431 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 5.1+ MB
# question_id        0
# question           0
# syllabus_id        0
# answer           581
# question_type      0
# dtype: int64

# %%
df = df.dropna()   # Should have dropped single choice questions though
df.isnull().sum()
# Out:
# question_id      0
# question         0
# syllabus_id      0
# answer           0
# question_type    0
# dtype: int64

# %% [markdown]
# ### **Preprocessing**

# %%
pd.options.mode.chained_assignment = None

df['question'] = df['question'].str.lower()
df['answer'] = df['answer'].str.lower()
df['question_type'] = df['question_type'].str.lower()

df
# Out:
#         question_id                                           question  \
# 0           2073346         how many π bonds are present in ferrocene
# 1           2073324  what is covalency of chlorine atom in second e...
# 2           2073225  in solid x atoms goes to corner of the cube an...
# 3           2073215  calculate value of x y here x and y are the to...
# 4           2073202  in phosphorus acid if x is number of non bondi...
# ...             ...                                                ...
# 134426       420545  a dice is rolled thrice the probability of get...
# 134427       420544  a dice is rolled thrice the probability of get...
# 134428       420543                       subjective english question
# 134429       415580                       question subjective english
# 134430       415579                      subjective english questions
#
#        syllabus_id                                             answer  \
# 0           700295                                                 a
# 1           698013                                                 a
# 2           700078                         no of x atoms 8 18 2 12 2
# 3           697895  stryde images 2022 04 11 202204110162130016496...
# 4           697895  stryde images 2022 04 11 202204119693370016496...
# ...            ...                                                ...
# 134426          -1                                         frac 5 24
# 134427          -1                                         frac 5 24
# 134428          -1                                 answer_subjective
# 134429          -1                           answer subjective hindi
# 134430          -1                           answer of this question
#
#                  question_type
# 0          subjective question
# 1          subjective question
# 2          subjective question
# 3          subjective question
# 4          subjective question
# ...                        ...
# 134426  single choice question
# 134427  single choice question
# 134428     subjective question
# 134429     subjective question
# 134430     subjective question
#
# [133850 rows x 5 columns]

# %%
# Data we're working with currently

df['question_type'].value_counts()
# Out:
# single choice question      89115
# subjective question         43896
# multiple choice question      656
# integer question              183
# Name: question_type, dtype: int64

# %%
single_choice_ques_df = df[df['question_type'] == 'single choice question']
subjective_ques_df = df[df['question_type'] == 'subjective_question']
multiple_choice_ques_df = df[df['question_type'] == 'multiple choice question']
integer_question = df[df['question_type'] == 'integer question']

# %%
print("Number of Questions in this pre-processed data :", df.shape[0])
print(df.shape)
# Out:
# Number of Questions in this pre-processed data : 133850
# (133850, 5)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### **FEATURE ENGINEERING ON THE DATASET**
#
# - Character length of a question
# - Number of words in a question

# %%
# Character length of a question

df["len"] = df["question"].str.len()-1

# %%
# Number of words
df["words"] = df["question"].str.strip().str.split().str.len()

# %%
# Number of common words

def to_lower(d):
  a = [[x.lower() for x in s] for s in d]
  return a 

def common_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return len(w1 & w2)

def total_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return (len(w1|w2))

# %%
# Question lengths statistics

sns.displot(df['len'])
print('Minimum characters',df['len'].min())
print('Maximum characters',df['len'].max())
print('Average number of characters',int(df['len'].mean()))
# Out:
# Minimum characters 1
# Maximum characters 4919
# Average number of characters 84

# %%
df
# Out:
#         question_id                                           question  \
# 0           2073346         how many π bonds are present in ferrocene
# 1           2073324  what is covalency of chlorine atom in second e...
# 2           2073225  in solid x atoms goes to corner of the cube an...
# 3           2073215  calculate value of x y here x and y are the to...
# 4           2073202  in phosphorus acid if x is number of non bondi...
# ...             ...                                                ...
# 134426       420545  a dice is rolled thrice the probability of get...
# 134427       420544  a dice is rolled thrice the probability of get...
# 134428       420543                       subjective english question
# 134429       415580                       question subjective english
# 134430       415579                      subjective english questions
#
#        syllabus_id                                             answer  \
# 0           700295                                                 a
# 1           698013                                                 a
# 2           700078                         no of x atoms 8 18 2 12 2
# 3           697895  stryde images 2022 04 11 202204110162130016496...
# 4           697895  stryde images 2022 04 11 202204119693370016496...
# ...            ...                                                ...
# 134426          -1                                         frac 5 24
# 134427          -1                                         frac 5 24
# 134428          -1                                 answer_subjective
# 134429          -1                           answer subjective hindi
# 134430          -1                           answer of this question
#
#                  question_type  len  words
# 0          subjective question   41      8
# 1          subjective question   58     10
# 2          subjective question  126     25
# 3          subjective question  156     28
# 4          subjective question  143     32
# ...                        ...  ...    ...
# 134426  single choice question  114     21
# 134427  single choice question  114     21
# 134428     subjective question   27      3
# 134429     subjective question   27      3
# 134430     subjective question   28      3
#
# [133850 rows x 7 columns]

# %%
# Questions with len = 1,2,3 Are they of any use ?

#  df.loc[df['len'] == 3]

# No questions of length 1 and 2 seems senseful so removing them

df = df.drop(df[df['len'] <= 2].index)

df.loc[df['len'] <= 3]
# Out:
#         question_id question syllabus_id  \
# 20795       1606350     she       511225
# 22432       1456491     she       511224
# 48052       1808367     knk           -1
# 59596       1747934     gnp       667999
# 73576       1433929     how       509609
# 73582       1433621     you       509609
# 73591       1433612     she       509609
# 73593       1434533     how       509609
# 73594       1434324     you       509609
# 123212       498479     ram         4407
# 124203       495304     tom         4774
# 124725       494480     she         4770
# 124744       494352     she         4770
# 125099       490534     she         4766
# 125101       490532     she         4766
# 134374       415898     sdf           -1
# 134376       415896     sdf           -1
#
#                                                    answer  \
# 20795   had taken a formal training before joining the...
# 22432                            is trying hard to excel
# 48052                                               bbjb
# 59596             gdp plus net factor income from abroad
# 73576   dare you enter my room without knocking at the...
# 73582   ought to apply in the form provided with the p...
# 73591   couldn't study yesterday because of the noise ...
# 73593                            dare you call me a liar
# 73594               need not smoke in a non smoking area
# 123212       has been serving the indian army since 1990
# 124203                        went to sleep so did becky
# 124725  exclaimed with disgust that their behaviour wa...
# 124744      asked her children how much they had studied
# 125099  had taken a formal training before joining the...
# 125101                           is trying hard to excel
# 134374                                            sdfsdf
# 134376                                               sdf
#
#                  question_type  len  words
# 20795   single choice question    3      1
# 22432   single choice question    3      1
# 48052      subjective question    3      1
# 59596   single choice question    3      1
# 73576   single choice question    3      1
# 73582   single choice question    3      1
# 73591   single choice question    3      1
# 73593   single choice question    3      1
# 73594   single choice question    3      1
# 123212  single choice question    3      1
# 124203  single choice question    3      1
# 124725  single choice question    3      1
# 124744  single choice question    3      1
# 125099  single choice question    3      1
# 125101  single choice question    3      1
# 134374  single choice question    3      1
# 134376     subjective question    3      1

# %%
sns.displot(df['words'])
print('Minimum words',df['words'].min())
print('Maximum words',df['words'].max())
print('Average num of words',int(df['words'].mean()))
# Out:
# Minimum words 1
# Maximum words 1017
# Average num of words 15

# %%
# Questions with words = 1,2,3 Are they of any use, seems useful ? yes some seems useful

df.loc[df['words'] <= 2]
# Out:
#         question_id                      question syllabus_id  \
# 144         2072214                 biosphere is       697984
# 664         2072040                 verdigris is       700295
# 1091        2060711          associated colloids       700206
# 1166        2060561         peptization involves       700206
# 1183        2060514                 all colloids       700206
# ...             ...                           ...         ...
# 134417       412759  subjective englishkajhsdklf           -1
# 134419       412507  subjective englishkajhsdklf           -1
# 134421       412240                         kjkj           -1
# 134422       412239  subjective englishkajhsdklf           -1
# 134424       420547               ufdkifdfjdkfjd           -1
#
#                                                    answer  \
# 144           in which individual interact to each other
# 664                                 basic copper acetate
# 1091    lower the surface tension and raise the viscos...
# 1166              disintegration of colloidal aggregates
# 1183                               are two phase systems
# ...                                                   ...
# 134417                          subjective hindiasdfasdf
# 134419                          subjective hindiasdfasdf
# 134421                                       dfdkfkdjfjd
# 134422                          subjective hindiasdfasdf
# 134424                                fdfjdkjfdfdkfdkjfd
#
#                  question_type  len  words
# 144     single choice question   12      2
# 664     single choice question   12      2
# 1091    single choice question   19      2
# 1166    single choice question   20      2
# 1183    single choice question   12      2
# ...                        ...  ...    ...
# 134417     subjective question   27      2
# 134419     subjective question   27      2
# 134421  single choice question    4      1
# 134422     subjective question   27      2
# 134424     subjective question   14      1
#
# [1311 rows x 7 columns]

# %%
from collections import OrderedDict
import operator
import nltk
from nltk import bigrams, trigrams, word_tokenize
from collections import Counter, defaultdict
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
ques = df['question'].tolist()

ans = df['answer'].tolist()
types = df['question_type'].tolist()

for i in range(len(ques)):
    ques[i] = ques[i].lower()
    ans[i] = str(ans[i]).lower()
    types[i] = types[i].lower() 

# ques = list(set(ques))

# sz = 10000
# ques

len(ques)
# Out:
# 133823

# %%
unigrams = []

for sent in ques :
  unigrams.append(set(nltk.word_tokenize(sent)))

# unigrams

# %%
req_pairs = []
threshold = 0.8

sz = 30000

for i in range(0,sz-1):

  s1 = unigrams[i]
  print(i)

  for j in range(i+1,sz):

    s2 = unigrams[j]

    union = len(s1|s2)
    common = len(s1&s2)

    jaccard_sim =  common/union

    if(jaccard_sim >= threshold):
      req_pairs.append([ques[i],ques[j],ans[i],ans[j],types[i],types[j],jaccard_sim])
# Out:
# Streaming output truncated to the last 5000 lines.
# 24999
# 25000
# 25001
# 25002
# 25003
# 25004
# 25005
# 25006
# 25007
# 25008
# 25009
# 25010
# 25011
# 25012
# 25013
# 25014
# 25015
# 25016
# 25017
# 25018
# 25019
# 25020
# 25021
# 25022
# 25023
# 25024
# 25025
# 25026
# 25027
# 25028
# 25029
# 25030
# 25031
# 25032
# 25033
# 25034
# 25035
# 25036
# 25037
# 25038
# 25039
# 25040
# 25041
# 25042
# 25043
# 25044
# 25045
# 25046
# 25047
# 25048
# 25049
# 25050
# 25051
# 25052
# 25053
# 25054
# 25055
# 25056
# 25057
# 25058
# 25059
# 25060
# 25061
# 25062
# 25063
# 25064
# 25065
# 25066
# 25067
# 25068
# 25069
# 25070
# 25071
# 25072
# 25073
# 25074
# 25075
# 25076
# 25077
# 25078
# 25079
# 25080
# 25081
# 25082
# 25083
# 25084
# 25085
# 25086
# 25087
# 25088
# 25089
# 25090
#   'a ',
#   'subjective question',
#   'subjective question',
#   1.0],
#  ['calculate value of x y here x and y are the total number of bonds in benzene and benzyne respectively which are formed by overlapping of hybridized orbitals ',
#   'calculate value of x y here x and y are the total number of bonds in benzene and benzene respectively which are formed by overlapping of hybridized orbitals ',
#   'stryde images 2022 04 11 20220411016213001649675720 png ',
#   '1 stryde images 2022 04 11 20220411774465001649670595 png x 12 y 11 x y 1 ',
#   'subjective question',
#   'subjective question',
#   0.9545454545454546],
#  ['in phosphorus acid if x is number of non bonding electron pairs y is number of σ bonds and z is number of π bonds then calculate value of y z x ',
#   'in phosphorus acid if x is number of non bonding electron pairs y is number of σ bonds and z is number of π bonds then calculate value of y z x ',
#   'stryde images 2022 04 11 20220411969337001649675598 png x 6 y 6 z 1 y z x 6 1 6 0 ',
#   'stryde images 2022 04 11 20220411001176001649666283 png x 6 y 6 z 1 y z x 6 1 6 0 ',
#   'subjective question',
#   'subjective question',
#   1.0],
#  ['calculate the value of x y z here x y and z are total number of non bonded electron pair s π bond s and sigma σ bonds in hydrogen phosphite ion respectively ',
#   'calculate the value of x y z here x y and z total number of non bonded electron pair s pie π bond s and sigma bonds in hydrogen ion respectively ',
#   'stryde images 2022 04 11 20220411047905001649675549 png x 7 y 1 z 57 1 5 3 ',
#   'stryde images 2022 04 11 20220411409302001649669785 png ',
#   'subjective question',
#   'subjective question',
#   0.8571428571428571],
#  ['find out total number of representative elements among the given elements cd nb ta te ra mo po pd tc ',
#   'find out total number of representative elements among the given elements cd nb ta te ra mo po pd tc ',
#   'te po ra ',
#   'integer_type_answer ',
#   'subjective question',
#   'integer question',
#   1.0],
#  ['under the identical conditions of temperature the density of a gas x is two times to that of gas y while molecular mass of gas y is three times that of x calculate the ratio of pressure of x and y ',
#   'under the identical conditions of temperature the density of a gas x is three times to that of gas y while molecular mass of gas y is three times that of x calculate the ratio of pressure of x and y ',
#   '6 ',
#   'integer_type_answer ',
#   'subjective question',
#   'integer question',
#   0.9583333333333334],
#  ['which of the following has largest number of isomers ',
#   'which one of the following has largest number of isomers ',
#   'co en 2cl2 ',
#   'co en 2 scn 2 ',
#   'single choice question',
#   'single choice question',
#   0.8888888888888888],
#  ['which of the following has largest number of isomers ',
#   'which of the following has largest number of isomers ',
#   'co en 2cl2 ',
#   'co en 2cl2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following has largest number of isomers ',
#   'which one of the following has largest number of isomers ',
#   'co en 2cl2 ',
#   'co en 2cl2 ',
#   'single choice question',
#   'single choice question',
#   0.8888888888888888],
#  ['h o m o highest occupied molecular orbital of co molecular is ',
#   'h o m o highest occupied molecular orbital of co molecular is ',
#   'non bonding m o with slight antibonding character ',
#   'non bonding m o with slight antibonding character ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the π acid ligand which uses its d orbital during synergic bonding in its complex compound ',
#   'the π acid ligand which uses its d orbital during synergic bonding in its complex compound ',
#   'pr3 ',
#   'pr3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'naoh does not absorb water from atmosphere ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'li2co3 and mgco3 both are thermally stable ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'lyophilic sols need stabilizing agent ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'sulphur sol is multimolecular colloid and hydrophobic in nature ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'formation of micelles takes place below cmc ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'lyophobic sols particles are hydrated ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   "however great the pressure applied a gas cannot be liquified below it's critical temp ",
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'me 2sicl2 on hydrolysis and then on subsequent intermolecular condensation gives cross linked structure ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'molar conductivity of a strong electrolyte increases with dilution because ionisation increases with dilution ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select incorrect statement ',
#   'select incorrect statement ',
#   'mn cation is present in chlorophyll ',
#   'a catalyst increases the speed of both forward and backward reaction hence equilibrium position is changed ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['coordination compounds have great importance in biological systems in this context which of the following statements is incorrect ',
#   'coordination compounds have great importance in biological systems in this context which of the following statements is incorrect ',
#   'chlorophylls are green pigments in plants and contain calcium ',
#   'chlorophylls are green pigments in plants and contain calcium ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the correct order of increasing solubility in water is ',
#   'the correct order of increasing solubility in water is ',
#   'nahco3 khco3 rbhco3 ',
#   'nahco3 khco3 rbhco3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the incorrect order of solubility in water is ',
#   'the incorrect order of solubility in water is ',
#   'bes2o3 mgs2o3 cas2o3 ',
#   'bas2o3 mgs2o3 cas2o3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the correct order of bond angles is ',
#   'the correct order of increasing bond angles is ',
#   'no2 no2 no2 ',
#   'of2 h2o cl2o clo2 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['the correct order of bond angles is ',
#   'the correct order of bond angles is ',
#   'no2 no2 no2 ',
#   'o b r 2 o c l 2 h 2 o o f 2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the correct order of bond angles is ',
#   'the correct order of bond angles is ',
#   'no2 no2 no2 ',
#   'h2s nh3 sih4 bf3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the correct order of bond angles is ',
#   'the correct order of bond angles is ',
#   'no2 no2 no2 ',
#   'pf3 pcl3 pbr3 pi3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the correct order of increasing bond angles is ',
#   'the correct order of bond angles is ',
#   'of2 h2o cl2o clo2 ',
#   'o b r 2 o c l 2 h 2 o o f 2 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['the correct order of increasing bond angles is ',
#   'the correct order of bond angles is ',
#   'of2 h2o cl2o clo2 ',
#   'h2s nh3 sih4 bf3 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['the correct order of increasing bond angles is ',
#   'the correct order of bond angles is ',
#   'of2 h2o cl2o clo2 ',
#   'pf3 pcl3 pbr3 pi3 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['incorrect order of bond angle is ',
#   'incorrect order of bond angle is ',
#   'xeo4 clo4 so42 cf4 nsih33 osih32 ome2 ',
#   'pf3 pcl3 pbr3 ',
#   'multiple choice question',
#   'single choice question',
#   1.0],
#  ['incorrect order of bond angle is ',
#   'the incorrect order of bond angle is ',
#   'xeo4 clo4 so42 cf4 nsih33 osih32 ome2 ',
#   'osih32 clo2 ',
#   'multiple choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['select correct match ',
#   'select correct match ',
#   'anions separated by reagent co 32 hco3 cacl 2 ',
#   'cobrcl h2o 4 ag cn 2 co ordination isomerism ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following compounds does not exist ',
#   'which of the following does not exist ',
#   'cro2br2 ',
#   'ko4 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['in nessler s reagent the ion present is ',
#   'in nessler s reagent the ion present is ',
#   'hgi42 ',
#   'h g i 4 2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the incorrect match ',
#   'select the incorrect match ',
#   'fe2 fe cn 6 4 red brown colouration ',
#   'crno2nh35zncl4 crno3nh35zncl4 linkage isomerism ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the incorrect match ',
#   'select the incorrect match ',
#   'fe2 fe cn 6 4 red brown colouration ',
#   'statement shape example reduction in axial bond angle is more than that of in equatorial bond angle stryde images 2022 04 07 20220407973686001649323883 png sf4 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the incorrect match ',
#   'select the incorrect match ',
#   'fe2 fe cn 6 4 red brown colouration ',
#   'fe2 fe cn 6 4 red brown colouration ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following practices will not come under green chemistry ',
#   'which of the following practices will not come under green chemistry ',
#   'using plastic cans for neatly storing substances ',
#   'using plastic cans for neatly storing substances ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following practices will not come under green chemistry ',
#   'which of the following practices will not come under green chemistry ',
#   'using plastic cans for neatly storing substances ',
#   'using plastic cans for neatly storing substances ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements about photochemical smog is wrong ',
#   'which of the following statements about photochemical smog is wrong ',
#   'it has low concentration of oxidising agent ',
#   'it has a low concentration of the oxidising agent ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements about photochemical smog is wrong ',
#   'which of the following statement is wrong about photochemical smog ',
#   'it has low concentration of oxidising agent ',
#   'it has high reducing property ',
#   'single choice question',
#   'single choice question',
#   0.8181818181818182],
#  ['which of the following statements about photochemical smog is wrong ',
#   'which of the following statements is false about photochemical smog ',
#   'it has low concentration of oxidising agent ',
#   'it occurs in cool and humid climate ',
#   'single choice question',
#   'single choice question',
#   0.8181818181818182],
#  ['which of the following statements about photochemical smog is wrong ',
#   'which of the following statements is false about photochemical smog ',
#   'it has low concentration of oxidising agent ',
#   'it occurs in cool and humid climate ',
#   'single choice question',
#   'single choice question',
#   0.8181818181818182],
#  ['persons working in cement plants and lime stone quarries are more prone to disease like ',
#   'persons working in cement plants and limestone quarries are more prone to disease like ',
#   'silicosis ',
#   'silicosis ',
#   'single choice question',
#   'single choice question',
#   0.8125],
#  ['gas that can be collected over water is ',
#   'gas that cannot be collected over water is ',
#   'so2 ',
#   'so2 ',
#   'single choice question',
#   'single choice question',
#   0.8888888888888888],
#  ['gas that can be collected over water is ',
#   'a gas that cannot be collected over water is ',
#   'so2 ',
#   'so2 ',
#   'single choice question',
#   'single choice question',
#   0.8],
#  ['which of the following statement is wrong ',
#   'which of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'the stability of hydrides increases from nh3 to bih3 in group 15 of the periodic table ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is wrong ',
#   'which of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'in the estimation of carbon an organic compound is heated with cao in a combustion tube ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is wrong ',
#   'which of the following is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'sec 1 x π 4 x 2 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statement is wrong ',
#   'which of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'the wire of the metre bridge is made up of a material of high resistivity and high temperature coefficient ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is wrong ',
#   'which one of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'r a d i o w a v e s i n t h e f r e q u e n c y r a n g e 30 m h z t o 60 m h z a r e c a l l e d s k y w a v e s ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following statement is wrong ',
#   'which of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'all secondary alcohols give iodoform reaction ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is wrong ',
#   'which of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'at stopping potential on increasing the intensity of light photoelectric current increases ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is wrong ',
#   'which of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'the boiling points of aldehydes and ketones are lower than those of nonpolar alkanes of comparable molecular weight ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is wrong ',
#   'which of the following statement is wrong ',
#   'fishes grow as well in warm as in cold water ',
#   'alkaline earth metals have less electronegativity values compared to corresponding alkali metals and boron family elements due to stable ns2 configuration ',
#   'single choice question',
#   'multiple choice question',
#   1.0],
#  ['bhc and ddt act as ',
#   'ddt and bhc may act as ',
#   'carcinogens ',
#   'carcinogens ',
#   'single choice question',
#   'single choice question',
#   0.8333333333333334],
#  ['bhc and ddt act as ',
#   'bhc and ddt act as ',
#   'carcinogens ',
#   'carcinogen ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following co ordination compound has three stereoisomers ',
#   'which of the following co ordination compound has three stereoisomers ',
#   'cobr no2 en 2 ',
#   'cobr no2 en 2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['ultraviolet radiation is absorbed by ',
#   'solar ultraviolet radiation is absorbed by ',
#   'stratosphere ',
#   'stratosphere ',
#   'single choice question',
#   'single choice question',
#   0.8333333333333334],
#  ['fish die in water bodies polluted by sewage due to ',
#   'fish die in water bodies polluted by sewage due to ',
#   'reduction in oxygen ',
#   'reduction of oxygen ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['fish die in water bodies polluted by sewage due to ',
#   'fish die in water bodies polluted by sewage due to ',
#   'reduction in oxygen ',
#   'decrease in d o ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the incorrect order is ',
#   'the incorrect order is ',
#   'p character no2 no3 nh4 ',
#   'boiling point chcl3 ch3cl ccl4 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the incorrect order is ',
#   'the incorrect order is ',
#   'p character no2 no3 nh4 ',
#   'hf hcl hbr hi boiling point ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the basic component of smog is ',
#   'the basic component of the smog is ',
#   'no2 ',
#   'all of these ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['in which of the following species d orbitals having xz and yz two nodal planes involved in hybridization of central atom ',
#   'in which of the following species d orbital having xz and yz two nodal planes involved in hybridization of central atom ',
#   'if7 ',
#   'if7 ',
#   'single choice question',
#   'single choice question',
#   0.9],
#  ['the correct order of boiling point is ',
#   'the correct order of boiling point is ',
#   'm nitrophenol o nitrophenol ',
#   'hno3 ch3no3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the formula of azurite is ',
#   'the formula of azurite is ',
#   '2cuco3 cuoh2 ',
#   '2cuco3 cu oh 2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['silicate having one monovalent corner oxygen atom in each tetrahedron unit is ',
#   'silicate having one monovalent corner oxygen atom in each tetrahedron unit is ',
#   'sheet silicate ',
#   'sheet silicate ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['silicate having one monovalent corner oxygen atom in each tetrahedron unit is ',
#   'silicate having one monovalent corner oxygen atom in each tetrahedron unit is ',
#   'sheet silicate ',
#   'sheet silicate ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['zn and cd metals do not show variable valency because ',
#   'zn and cd metals do not show variable valency because ',
#   'their d subshells are completely filled ',
#   'their d subshells are completely filled ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['zn and cd metals do not show variable valency because ',
#   'zn and cd metals do not show variable valency because ',
#   'their d subshells are completely filled ',
#   'their d subshells are completely filled ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the third ionization energy of aluminium is greater than that of phosphorus ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'sodium and potassium burn in dry oxygen excess giving peroxides ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the stability constant of cu nh3 4 2 is greater than that of cu en 2 2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which one of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'electron gain enthalpy decreases from fluorine to iodine in the group ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the shape of an orbital is given by the principal quantum number ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'a second order reaction must be a bimolecular elementary reaction ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'in f2 molecule the energy of σ2pz is more than π2px and π2py ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'a deep red solution of complex ion fe3 oh 2 ch2coo 6 on boiling with water produces a greenish yellow precipitate ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'reducing agent of haematite in blast furnace is coke in upper part and co in lower part of furnace ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the si o bonds are weaker than c o bonds because of bigger size of silicon atom ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the intensity of red colour increases when oxalic acid is added to a solution containing iron iii nitrate and potassium thiocyanate ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'ruby appears due to presence of co3 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'sn2reactioninvolvescarboniumionformation ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'in transition state one end carries δ and another end carries δ charge ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'period of f x sinx x is 2π ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'lyophobic colloids are more hydrated than lyophilic colloids ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'both o2 and are o3 paramagnetic ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'in transition state one end carries δ and another end carries δ charge ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   "tollen's reagent is used in detection of unsaturation ",
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'stryde images 2021 02 28 20210228292204001614513839 png is more stable carbocation than stryde images 2021 02 28 20210228961364001614513879 png ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which one of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'hf is a stronger acid than hcl ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   '3o2 dischargesilent electric2o3 δh 284 5 kj ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'rna contains deoxyribose sugar ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'hydrogen shows an oxidation state of 1 in covalent hydrides ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'in h2o2 the two hydroxyl groups lie on the same plane ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'ionic character alkali metals halides decreases down the group ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'ionic hydrides are very good conductors of electricity in solid state ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'σ electrons are referred to as mobile electrons ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'mg cannot form complexes ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'metallic hydrides are formed by many s block and p block elements ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'in k3 fe cn 6 the ligand has satisfied only the secondary valency of ferric ion ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'both o2 and o3 are paramagnetic ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the carbon atom is sp2 hybridized in the co2 molecule as well as the molecule of its hydrate h2co3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'p q p q ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'mode 3 median 2 mean ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the mean deviation of the data is least when deviations are taken about the mean ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'stryde images 2021 02 01 20210201126848001612160772 png ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'p q q p is a contradiction ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'b2h6 is not an electron deficient molecule ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'b oh 3 does not donate a proton and hence does not form any salt with naoh ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'orthoboric acid undergoes intramolecular hydrogen bonding ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'bf3 exists as dimer ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'electron gain enthalpy is not an absolute value ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'n c r n 1 c r n c n r ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'if centre of mass remains at rest then net work done by the forces acting on the system must be zero ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'none of these ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'the mass of proton and electron are nearly the same ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'aufbau principle is incorrect for cases where energy difference between ns and n 1 d sub shell is larger ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'some spectral lines of an element may have the same wave number ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'the relative lowering of vapour pressure is directly propertional to the original pressure ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'a vector has only magnitude whereas a scalar has both magnitude and direction ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'a2 b c b2 c a c2 a b a b b c c a ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'a 3 1 a 3 4 a 1 a 1 a 2 1 a 2 a 1 a 2 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   '22003 is having unit place digit as 2 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'l c m o f 2 π π 3 2 π 3 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'none of these ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'set of integers is closed under addition subtraction multiplication and division ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'none of these ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   '4 2 x 3 4 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   '710 210 is not divisible by 16839 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'none of these ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'x 2 x x 2 x x 0 1 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'none of these ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'i f α β 1 t h e n α l o g α β β l o g β α i s g r e a t e r t h a n 1 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'none of these ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'largest of three consecutive natural numbers can be written as sum of the cubes of other two ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'a b b a i s m u l t i p l e o f 11 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'if a b 0 and a3 b3 2 then a b 2 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   't h e v a l u e o f t h e e x p r e s s i o n c o t 45 c o t 35 c o t 10 t a n 45 t a n 35 t a n 10 i s e q u a l t o 2 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'a b c a b a c ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'a b a b ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'a photovoltaic device operates in forward bias ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'floating soaps are obtained by beating tiny air bubbles after their hardening ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   "tollens' reagent is used in detection of unsaturation ",
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'activation energy for the forward reaction equals to activation energy for the reverse reaction ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'all proteins are enzymes ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statements is incorrect ',
#   'which one of the following statements is incorrect ',
#   'mercurous ion exists as hg ',
#   'chelate complexes have low stability constant ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following statements is incorrect ',
#   'which of the following is incorrect ',
#   'mercurous ion exists as hg ',
#   'both o2 and o3 are paramagnetic ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['the two compounds pentaamminesulphatocobalt iii bromide and pentaamminesulphatocobalt iii chloride represent ',
#   'the two compounds sulphatopentaamminecobalt iii bromide and sulphatopentaamminecobalt iii chloride represent ',
#   'no isomerism ',
#   'no isomerism ',
#   'single choice question',
#   'single choice question',
#   0.8],
#  ['from the stability __ constant hypothetical values given below predict which is the strongest ligand ',
#   'from the stability constant hypothetical values given below predict which is the strongest ligand ',
#   'cu2 4nh cu cn 42 k 2 50 1027 ',
#   'cu2 4cn cu cn 4 2 k 2 0 1027 ',
#   'single choice question',
#   'single choice question',
#   0.9285714285714286],
#  ['correct order of bond angle is ',
#   'the correct order of bond angle is ',
#   'c h3 c f3 ',
#   'n s i h 3 3 p s i h 3 2 ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['correct order of bond angle is ',
#   'the correct order of bond angle is ',
#   'c h3 c f3 ',
#   'h2o of2 sf2 h2s ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['for an octahedral comple _x_ which of the following _d _ electron configuration will give ma _x_ imum cfse ',
#   'for an octahedral comple _x_ which of the following _d_ electron configuration will give ma _x_ imum cfse ',
#   'low spin d5 ',
#   'low spin with d5 configuration ',
#   'single choice question',
#   'single choice question',
#   0.8421052631578947],
#  ['when steam is passed over red hot iron the substances formed are ',
#   'when steam is passed over red hot iron the substances formed are ',
#   'fe3o4 h2 ',
#   'fe3o4 h2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following order of cfse is incorrect ',
#   'which of the following order of cfse is incorrect ',
#   'ni dmg 2 ni en 2 2 ',
#   'ni dmg 2 ni en 22 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following order of cfse is incorrect ',
#   'which of the following order is incorrect ',
#   'ni dmg 2 ni en 2 2 ',
#   'electrical conductance f aq cl aq s aq 2 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following order of cfse is incorrect ',
#   'which of the following order is incorrect ',
#   'ni dmg 2 ni en 2 2 ',
#   'e l e c t r i c a l c o n d u c t a n c e f a q c l a q s a q 2 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following statements about anhydrous aluminium chloride is correct ',
#   'which of the statements about anhydrous aluminium chloride is correct ',
#   'it can exist as alcl3 molecule in vapour it sublimes at 180oc under vacuum ',
#   'it sublimes at 100 c under vacuum ',
#   'multiple choice question',
#   'single choice question',
#   0.9090909090909091],
#  ['which of the following statement is false ',
#   'which of the following statement is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'pt en 2 2 show geometrical isomerism as well as optical isomerism ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is false ',
#   'which of the following is false statement ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'all the b h bond distance in b2h6 are equal ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is false ',
#   'which of the following statement is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'london smog is oxidising in nature ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is false ',
#   'which of the following is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'fructose is oxidised by bromine water ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statement is false ',
#   'which of the following is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'p p q i s a c o n t r a d i c t i o n ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statement is false ',
#   'which of the following is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'alkyl halides have higher b p then corresponding alcohols ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following statement is false ',
#   'which of the following statement is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'the product of pressure and volume of fixed amount of a gas is independent of temperature ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is false ',
#   'which of the following statement is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'if gof x is one one both g x and f x are one one ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following statement is false ',
#   'which of the following is a false statement ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'diethyl ether and methyl isopropyl ether are chain isomers ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following statement is false ',
#   'which of following statement is false ',
#   'the milk of magnesia used as antacid is chemically mgo mgcl2 ',
#   'the half life of a reaction is half the time required for the reaction to go to completion ',
#   'single choice question',
#   'single choice question',
#   0.8571428571428571],
#  ['which of the following is arranged in order of increasing melting point ',
#   'which of the following is arranged in the order of decreasing melting point ',
#   'zn cu ni fe ',
#   'si al s p ',
#   'single choice question',
#   'single choice question',
#   0.8333333333333334],
#  ['calcium imide on hydrolysis gives gas b which on oxidation by bleaching powder gives gas c gas c on reaction with magnesium give compound d which on hydrolysis gives again gas b identify b c and d ',
#   'calcium imide on hydrolysis gives gas b which on oxidation by bleaching power gives gas c gas c on reaction with magnesium give compound d which on hydrolysis gives again gas b identify b c and d ',
#   'nh3 n2 mg3n2 ',
#   'nh3 n2 mg3n2 ',
#   'single choice question',
#   'single choice question',
#   0.9130434782608695],
#  ['among the following metals the most dense is ',
#   'among the following metals the most dense is ',
#   'osmium ',
#   'osmium ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'all are correct statements ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'all are correct statements ',
#   'all of these ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'all are correct statements ',
#   'internal energy of a real gas at a given temperature increases as the volume increases ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the only correct statement ',
#   'all are correct statements ',
#   'dz2 orbital has different shape from rest of all d orbitals ',
#   'single choice question',
#   'single choice question',
#   0.8],
# ...
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all are correct statements ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all are correct statements ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'osmotic pressure depends on temperature and concentration but is independent of the nature of the membrane ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'elemental sodium is easily oxidized ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all of the above ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'polydisperse polymers are less homogeneous or simply heterogeneous ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'solubility of alkali carbonates is in order li2co3 na2co3 k2co3 rb2co3 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement s ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all are correct statements ',
#   'single choice question',
#   'single choice question',
#   0.8],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'ko2 is paramagnetic in nature ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'london smog forms in the early morning hours and los angeles smog forms during the day ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'at absolute zero only para hydrogen exists ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all of the above are correct ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all of the above are correct statements ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'corrosion of iron can be minimized by forming an impermeable barrier at its surface ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all of the above are correct statements ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'a catalyst increases the rate of forward and backward reaction by same extent ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'under identical condition of pressure and temperature equal volume of gases always consists of equal number of atoms ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'specific conductivity decreases with dilution ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all of the above are correct ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['select the correct statement ',
#   'select the correct statement ',
#   'hybridization of both sulphur in h2s2o5 pyrosulphurous acid is same but oxidation state of both sulphur are different ',
#   'all of these ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the gas leaked from a storage tank of the union carbide plant in bhopal gas tragedy was ',
#   'the gas leaked from a storage tank of the union carbide plant in bhopal gas tragedy was ',
#   'methyl isocyanate ',
#   'methyl isocyanate ',
#   'single choice question',
#   'multiple choice question',
#   1.0],
#  ['identify the incorrect statement from the following ',
#   'identify the incorrect statement from the following ',
#   'ozone absorbs intra red radiations ',
#   'ozone absorbs infrared radiations ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['identify the incorrect statement from the following ',
#   'identify the incorrect statement from the following ',
#   'ozone absorbs intra red radiations ',
#   'modulation index m is kept 1 to avoid distortion ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['identify the wrong statements in the following ',
#   'identify the wrong statements in the following ',
#   'ozone layer does not permit infrared radiation from the sun to reach the earth ',
#   'chlorofluorocarbons are responsible for ozone layer depletion ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following is responsible for depletion of ozone layer in upper strata of the atmosphere ',
#   'which of the following is responsible for the depletion of the ozone layer in the upper strata of the atmosphere ',
#   'freons ',
#   'freons ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following is responsible for depletion of ozone layer in upper strata of the atmosphere ',
#   'which of the following is responsible for depletion of the ozone layer in the upper strata of the atmosphere ',
#   'freons ',
#   'freons ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['ozone in stratosphere is depleted by ',
#   'ozone in stratosphere is depleted by ',
#   'cf2cl2 ',
#   'cf2cl2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the smog is essentially caused by the presence of ',
#   'the smog is essentially caused by the presence of ',
#   'oxides of sulphur and n2 ',
#   'oxides of sulphur and nitrogen ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['when rain is accompanied by a thunderstorm the collected rain water will have ph ',
#   'when rain is accompanied by a thunderstorm the collected rain water will have a ph value ',
#   'slightly lower than that of rain water without thunderstorm ',
#   'slightly lower than that of rain water without thunderstorm ',
#   'single choice question',
#   'single choice question',
#   0.9285714285714286],
#  ['when rain is accompanied by a thunderstorm the collected rain water will have ph ',
#   'when rain is accompanied by a thunderstorm the collected rain water will have a ph value ',
#   'slightly lower than that of rain water without thunderstorm ',
#   'slightly lower than that of rain water without ',
#   'single choice question',
#   'single choice question',
#   0.9285714285714286],
#  ['when rain is accompanied by a thunderstorm the collected rain water will have ph ',
#   'when rain is accompanied by a thunderstorm the collected rain water will have a ph value ',
#   'slightly lower than that of rain water without thunderstorm ',
#   'slightly lower than that of rain water without thunderstorm ',
#   'single choice question',
#   'single choice question',
#   0.9285714285714286],
#  ['when rain is accompanied by a thunderstorm the collected rain water will have ph ',
#   'when rain is accompanied by a thunderstorm the collected rain water will have a ph value ',
#   'slightly lower than that of rain water without thunderstorm ',
#   'slightly lower than that of rain water without thunderstorm ',
#   'single choice question',
#   'multiple choice question',
#   0.9285714285714286],
#  ['which of the following is not optically __ active ',
#   'which of the following is not optically active ',
#   '_trans _ cocl2 en 2 ',
#   'trans cocl2 en 2 ',
#   'single choice question',
#   'single choice question',
#   0.8888888888888888],
#  ['the pollutants which come directly in the air from sources are called primary pollutants primary pollutants are sometimes converted into secondary pollutants which of the following belongs to secondary air pollutants ',
#   'the pollutants which come directly in the air from sources are called primary pollutants primary pollutants are sometimes converted into secondary pollutants which of the following belongs to secondary air pollutants ',
#   'peroxyacetyl nitrate ',
#   'peroxyacetyl nitrate ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which substance has the highest melting point ',
#   'which substance has the highest melting point ',
#   'sio2 ',
#   'sio2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following compounds has the lowest boiling point ',
#   'which of the following has lowest boiling point ',
#   'hcl ',
#   'o nitrophenol ',
#   'single choice question',
#   'single choice question',
#   0.8888888888888888],
#  ['which of the following compounds has the lowest boiling point ',
#   'which of the following hydrides has the lowest boiling point ',
#   'hcl ',
#   'h2s ',
#   'single choice question',
#   'single choice question',
#   0.8],
#  ['which of the following compounds has the lowest boiling point ',
#   'which of the following has lowest boiling point ',
#   'hcl ',
#   'o nitrophenol ',
#   'single choice question',
#   'single choice question',
#   0.8888888888888888],
#  ['which substance has the strongest london dispersion forces ',
#   'which substance has the strongest london dispersion forces ',
#   'snh4 ',
#   'snh4 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the compound formed on heating sodium metal in a current of dry ammonia gas is ',
#   'on heating sodium metal in a current of dry ammonia gas the compound formed is ',
#   'sodium amide ',
#   'sodium amide ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the compound formed on heating sodium metal in a current of dry ammonia gas is ',
#   'on heating sodium metal in a current of dry ammonia the compound formed is ',
#   'sodium amide ',
#   'sodium amide ',
#   'single choice question',
#   'single choice question',
#   0.9333333333333333],
#  ['potassium when heated strongly in oxygen it forms ',
#   'potassium when heated strongly in oxygen forms ',
#   'ko2 ',
#   'ko2 ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['which of the following pair the ean of central metal atom is not same ',
#   'which of the following pair the ean of central metal atom is not same ',
#   'ni co 4 and ni cn 4 2 ',
#   'ni co 4 and ni cn 4 2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following metal is expected to have the highest third ionization enthalpy ',
#   'which of the following metal is expected to have the highest third ionization enthalpy ',
#   'mn z 25 ',
#   'mn ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following is most soluble in water ',
#   'which of the following is most soluble in water ',
#   'liclo4 ',
#   'ag3 po4 ksp 1 8 10 18 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following is most soluble in water ',
#   'which of the following is soluble in water ',
#   'liclo4 ',
#   'c2h5oh ',
#   'single choice question',
#   'single choice question',
#   0.8888888888888888],
#  ['which of the following is most soluble in water ',
#   'which of the following is least soluble in water ',
#   'liclo4 ',
#   'c5h11oh ',
#   'single choice question',
#   'single choice question',
#   0.8],
#  ['element having highest i p value is ',
#   'element having highest i p value is ',
#   'he ',
#   'he ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['which of the following is the correct order for increasing bond angle ',
#   'which of the following is the correct order for increasing bond angle ',
#   'h3te h3se h3s h3o ',
#   'h3te h3se h3s h3o ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the correct order of atomic ionic radii is ',
#   'the correct order of atomic radii is ',
#   'sc ti v cr ',
#   'eu ce ho n ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['the correct order of atomic ionic radii is ',
#   'the correct order of ionic radii is ',
#   'sc ti v cr ',
#   'n3 o2 f na ',
#   'single choice question',
#   'single choice question',
#   0.875],
#  ['the o n o bond angle is maximum in ',
#   'the o n o bond angle is maximum in ',
#   'no2 ',
#   'n o 2 ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['the molecule having the largest bond angle is ',
#   'the molecule having the largest bond angle is ',
#   'h2o ',
#   'h2o ',
#   'single choice question',
#   'single choice question',
#   1.0],
#  ['dinitrogen and dioxygen are main constituents of air but these do not react with each other to form oxides of nitrogen because ',
#   'dinitrogen and dioxygen are main constituents of air but these do not react with each other to form oxides of nitrogen because of _________ ',
#   'the reaction is endothermic and requires very high temperature ',
#   'the reaction is endothermic and requires very high temperature ',
#   'single choice question',
#   'single choice question',
#   0.9545454545454546],
#  ['dinitrogen and dioxygen are main constituents of air but these do not react with each other to form oxides of nitrogen because ',
#   'dinitrogen and dioxygen are main constituents of air but these do not react with each other to form oxides of nitrogen because _ ',
#   'the reaction is endothermic and requires very high temperature ',
#   'the reaction is endothermic and requires very high temperature ',
#   'single choice question',
#   'single choice question',
#   0.9545454545454546],
#  ...]

# %%
duplicate_pairs = pd.DataFrame(req_pairs)

# %%
duplicate_pairs
# Out:
#                                                        0  \
# 0             how many π bonds are present in ferrocene
# 1      what is covalency of chlorine atom in second e...
# 2      calculate value of x y here x and y are the to...
# 3      in phosphorus acid if x is number of non bondi...
# 4      calculate the value of x y z here x y and z ar...
# ...                                                  ...
# 29336  the haber process and the hydrogenation of fat...
# 29337                   potassium manganate vii acts as
# 29338  when a carboxylic acid is heated with an alcoh...
# 29339  by choosing the correct option fill the follow...
# 29340                              during thunderstorms
#
#                                                        1  \
# 0                   how many π are present in ferrocene
# 1      what is covalency of chlorine atom in second e...
# 2      calculate value of x y here x and y are the to...
# 3      in phosphorus acid if x is number of non bondi...
# 4      calculate the value of x y z here x y and z to...
# ...                                                  ...
# 29336  the haber process and the hydrogenation of fat...
# 29337                   potassium manganate vii acts as
# 29338  when a carboxylic acid is heated with an alcoh...
# 29339  by choosing the correct option fill the follow...
# 29340                              during thunderstorms
#
#                                                        2  \
# 0                                                     a
# 1                                                     a
# 2      stryde images 2022 04 11 202204110162130016496...
# 3      stryde images 2022 04 11 202204119693370016496...
# 4      stryde images 2022 04 11 202204110479050016496...
# ...                                                  ...
# 29336  haber process element hydrogenation of fats el...
# 29337                                an oxidising agent
# 29338                                    esterification
# 29339          1 mixture 2 filtration 3 crystallisation
# 29340  the flash of lightning is seen few seconds bef...
#
#                                                        3  \
# 0                                                     a
# 1                                                     a
# 2      1 stryde images 2022 04 11 2022041177446500164...
# 3      stryde images 2022 04 11 202204110011760016496...
# 4      stryde images 2022 04 11 202204114093020016496...
# ...                                                  ...
# 29336  haber process element hydrogenation of fats el...
# 29337                                an oxidising agent
# 29338                                    esterification
# 29339          1 mixture 2 filtration 3 crystallisation
# 29340  the flash of lightning is seen few seconds bef...
#
#                             4                       5         6
# 0         subjective question     subjective question  0.875000
# 1         subjective question     subjective question  1.000000
# 2         subjective question     subjective question  0.954545
# 3         subjective question     subjective question  1.000000
# 4         subjective question     subjective question  0.857143
# ...                       ...                     ...       ...
# 29336  single choice question  single choice question  1.000000
# 29337  single choice question  single choice question  1.000000
# 29338  single choice question  single choice question  1.000000
# 29339     subjective question     subjective question  1.000000
# 29340  single choice question  single choice question  1.000000
#
# [29341 rows x 7 columns]
# Warning: total number of rows (29341) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
duplicate_pairs.to_csv('drive/MyDrive/Extramarks Project/Week4/File1.csv')

# %%
df[df['question'].str.lower() == 'which of the following is an example of a viral disease ']
# Out:
#        question_id                                           question  \
# 49930      1793289  Which of the following is an example of a vira...
#
#       syllabus_id      answer           question_type  len  words
# 49930      672638  Influenza   Single Choice Question   55     11

# %%
df[df['question'].str.lower() == 'which of the following is an example of a viral disease ']

# %% [markdown]
# ### **Word share / Jaccard Similarity Plot**

# %%
sns.distplot(df[df['is_duplicate'] == 0]['word_share'],label='non duplicate')
sns.distplot(df[df['is_duplicate'] == 1]['word_share'],label='duplicate')
plt.legend()
plt.show()

# %% [markdown]
# ## **Some data eyeballing to the cases where `word share is high` but still they are `not duplicates`.**
#
# - **Note** : `Word_share = Jaccard Similarity (JC)`
#
# - Number of shared terms over the number of all unique terms in both strings

# %%
vis_df = df.loc[(df['word_share'] == 1) & (df['is_duplicate']==0)]
vis_df[['question1','question2','word_share','is_duplicate']]

# %% [markdown]
# ⚡ Though questions have `Exact same (JC = 1)` vocabulary but `ordering` changes the meaning completely. This is where sementic nature is required to identify duplicates better.
#
# > Example :
# > - a) What kind of Asian guys do White girls like ?
# > - b) What kind of Asian girls do White guys like ?
#
# > Though some labels I feel are not appropriate and they should be duplicate indeed.
# > - a) Which laptop I should buy ?
# > - b) Which laptop should I buy ?

# %%
vis_df = df.loc[(df['word_share'] >= 0.9) & (df['is_duplicate']==0)]
vis_df[['question1','question2','word_share','is_duplicate']]

# Use inetractive table and sort acc to word_share values to see 0.9 word_share values first

# %% [markdown]
# ⚡ Though questions have `High word_share(JC)` vocabulary but a change of `Keyword` in the question changes it meaning.
#
# > Example : Negation sentences
# > - a) Who are the best science reporters not writing in English ?
# > - b) Who are the best science reporters writing in English ?
#
# > Example : Key noun is different
# > - a) How does a typical day in IIM C pass by ?
# > - b) How does a typical day in IIM A pass by ?
#
# > Example : More specification gets added
# > - a) How much does it cost to study in Canada ?
# > - b) How much does it cost to study medicine in Canada ?

# %%
# Some more cases where data is lexically similar but not duplicates

vis_df = df.loc[(df['word_share'] >= 0.75) & (df['is_duplicate']==0)]
vis_df[['question1','question2','word_share','is_duplicate']]

# %% [markdown]
# ⚡ Though questions have `Moderately high word_share(JC)` but a change of `Keyword` in the question changes it meaning.
#
# - **Observation** - In this chart we see short sentences whereas earlier there were long sentences, that's because changing a single word in small sentences drops down the Jaccard similarity more (Obvious though).

# %%
# More non-duplicate pairs visualization

threshold = 0.4
df.loc[(df['word_share'] >= threshold)][:200]

# %% [markdown]
# ## **Some data eyeballing to the cases where `word share is low` but still they are `duplicates`.**

# %%
vis_df = df.loc[(df['word_share'] <= 0.8) & (df['is_duplicate']==1)]
vis_df[['question1','question2','word_share','is_duplicate']][:1000]

# %% [markdown]
# What inference can we make from above ?

# %%
# def Unigram_distance(dataset):

#   model = defaultdict(lambda : 0)
#   total_count = 0 
#   for sentence in dataset:
#     sentence = nltk.word_tokenize(sentence)
#     for w1 in sentence:
#       model[w1] += 1
#       total_count += 1 ;

#   for w1 in model:
#       model[w1] /= total_count
  
#   return model

# %%
profile = ProfileReport(df, title="Quora", html={'style':{'full_width':True}})

# %%
profile.to_notebook_iframe()

# %%
# Preprocessing - ? se pehle space daaldo or remove it

# %%
drive.flush_and_unmount()
