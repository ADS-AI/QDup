# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkteshV/Question_duplicate_detection/blob/main/Week4/Cleaning_JEE_data_from_numericals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code heavily based on the Notebook from Week3 : https://colab.research.google.com/drive/1EyJZbbbjoSxHvqJtTxJBAtiP9S6CE7FL?authuser=1

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
import re
from string import punctuation
import torch
import pandas as pd
from time import time
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
nltk.download("")
# Out:
# [nltk_data] Error loading : Package '' not found in index
# False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tf.test.gpu_device_name()
# Out:
# ''

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv("drive/MyDrive/Extramarks Project/Dataset versions/EM-Data-with-answers.csv", index_col = 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#         question_id                                           question  \
# 0           2073394  Total number of species that can be oxidized b...
# 1           2073385  How many following Ammonium salts will evolve ...
# 2           2073373  There are some species given below i O2 ii CO ...
# 3           2073366  Consider the following compounds 1 H3CF 2 H2CF...
# 4           2073360  Find total number of reagents which can produc...
# ...             ...                                                ...
# 276057       420544  A dice is rolled thrice The probability of get...
# 276058       420543                       subjective english question
# 276059       415580                       question subjective english
# 276060       415579                      subjective english questions
# 276061       415578                  What are the 5 English questions
#
#        syllabus_id                                             answer  \
# 0           698013  All the species which are not in their highest...
# 1           698013  Ammonium salts having anions NO2 NO3 ClO4 and ...
# 2           697895  4 Molecular orbital configuration for upto 14 ...
# 3           697895  5 stryde images 2022 04 11 2022041195766400164...
# 4           698013  Conc H2SO4 2KI K2SO4 HI 12I2 Hg NO3 2 2KI HgI2...
# ...            ...                                                ...
# 276057          -1                                         frac 5 24
# 276058          -1                                 answer_subjective
# 276059          -1                           answer subjective hindi
# 276060          -1                           answer of this question
# 276061          -1                           answer of this question
#
#                  question_type
# 0          Subjective Question
# 1          Subjective Question
# 2          Subjective Question
# 3          Subjective Question
# 4          Subjective Question
# ...                        ...
# 276057  Single Choice Question
# 276058     Subjective Question
# 276059     Subjective Question
# 276060     Subjective Question
# 276061     Subjective Question
#
# [276062 rows x 5 columns]

# %%
len1 =len(df)
df = df.dropna()
print("Rows with NaN values: ", len1-len(df))
# Out:
# Rows with NaN values:  1846

# %%
df.head(2)
# Out:
#    question_id                                           question syllabus_id  \
# 0      2073394  Total number of species that can be oxidized b...      698013
# 1      2073385  How many following Ammonium salts will evolve ...      698013
#
#                                               answer        question_type
# 0  All the species which are not in their highest...  Subjective Question
# 1  Ammonium salts having anions NO2 NO3 ClO4 and ...  Subjective Question

# %%
print(df.sample(1).iloc[0]['question'])
print(df.sample(1).iloc[0]['question'])
print(df.sample(1).iloc[0]['question'])
print(df.sample(1).iloc[0]['question'])
print(df.sample(1).iloc[0]['question'])
# Out:
# The 12 Alwars sang the glory of
# न म नल ख त क न स च ह न व स मय द ब धक च ह न ह
# Why is it not recommended to measure the temperature of boiling water using a clinical thermometer
# क स प र रम भ ह न व ल उपव क य क न स आश र त उपव क य ह त ह
# Put the verbs in brackets into the simple past or past continuous tense 1 This bull normally ______ not chase people unless something ______ make him angry 2 Kelly said that she ______ not like her present flat and _____ try to find another 3 John _____ find a ring as he ______ dig in the garden 4 He just ____ start when I ______ see it so I couldn t judge 5 While he ______ water the plants in the garden it _____ begin to rain

# %% [markdown]
# ######Few samples

# %%
df.iloc[-200:-190]
# Out:
#         question_id                                           question  \
# 275860       414979  The adjective which forms an adverb with ily i...
# 275861       414978    The adverb indispensably means _______________
# 275862       414976                      Birds fly ________ fish swim
# 275863       414975  Choose the appropriate conjunction You will pa...
# 275864       414974  Choose the appropriate conjunction Take care o...
# 275865       414933  Choose the appropriate conjunction Answer the ...
# 275866       414932  Choose the appropriate conjunction I returned ...
# 275867       414931  Choose the appropriate conjunction Many things...
# 275868       414930  Choose the appropriate conjunction I am so tir...
# 275869       414929  Choose the appropriate conjunction Don t waste...
#
#        syllabus_id        answer           question_type
# 275860        3623        angry   Single Choice Question
# 275861        3623  importantly   Single Choice Question
# 275862        3632          and   Single Choice Question
# 275863        3632           if   Single Choice Question
# 275864        3632       before   Single Choice Question
# 275865        3632       before   Single Choice Question
# 275866        3632        after   Single Choice Question
# 275867        3632        since   Single Choice Question
# 275868        3632         that   Single Choice Question
# 275869        3632         lest   Single Choice Question

# %%
df.iloc[-300:-290]
# Out:
#         question_id                                           question  \
# 275760       416272        Bharat was ___________________ for the job
# 275761       416271  The population of China is greater ___________...
# 275762       416270               Either you or I ___________________
# 275763       416269       The collective noun choir means ___________
# 275764       416268  The proper noun in the sentence is ___________...
# 275765       416267  The correct collective noun in the following i...
# 275766       416266  John has hatred for swimming The abstract noun...
# 275767       416265    The correct adjective order is _______________
# 275768       416264  We are a good team as ____________________ our...
# 275769       416263          Choose the correctly punctuated sentence
#
#        syllabus_id                                             answer  \
# 275760        4415                                           perfect
# 275761        4415                                      than that of
# 275762        4415                                       am mistaken
# 275763        3637                                a group of singers
# 275764        3637                                            Kanpur
# 275765        3637                               a pride of peacocks
# 275766        3637                                            hatred
# 275767        3620  a hardworking short forty year old Punjabi dri...
# 275768        3636                                           each of
# 275769        3616                        Come here Tom and sit down
#
#                  question_type
# 275760  Single Choice Question
# 275761  Single Choice Question
# 275762  Single Choice Question
# 275763  Single Choice Question
# 275764  Single Choice Question
# 275765  Single Choice Question
# 275766  Single Choice Question
# 275767  Single Choice Question
# 275768  Single Choice Question
# 275769  Single Choice Question

# %%
df.iloc[-500:-490]
# Out:
#         question_id                                           question  \
# 275560       418869  The correct superlative degree of the adjectiv...
# 275561       418572  The rules made for the Buddhist Sangha were wr...
# 275562       418571  Buddha's main teaching was based on the fact t...
# 275563       418570                       The founder of Buddhism was
# 275564       418569          The patient had died before ____________
# 275565       418568  Amy was studying while Mollie _______________ ...
# 275566       418567      Last night at 6 PM __________________ dinner
# 275567       418566                                       Last year I
# 275568       418565  Isabel rarely ____________ to attend the music...
# 275569       418544  Yesterday my mother and I ______________ to wa...
#
#        syllabus_id                                       answer  \
# 275560        3620                                     biggest
# 275561      744376                               Vinaya Pitaka
# 275562      744376  Life is full of sufferings and unhappiness
# 275563      744376                                   Siddartha
# 275564        3659                             the doctor came
# 275565        3659                                  was making
# 275566        3659                                I was eating
# 275567        3659                                took my exam
# 275568        3659                                       comes
# 275569        3659                                        went
#
#                  question_type
# 275560  Single Choice Question
# 275561  Single Choice Question
# 275562  Single Choice Question
# 275563  Single Choice Question
# 275564  Single Choice Question
# 275565  Single Choice Question
# 275566  Single Choice Question
# 275567  Single Choice Question
# 275568  Single Choice Question
# 275569  Single Choice Question

# %% [markdown]
# ### Cleaning the data

# %%
removed_questions = []
questions_left = []

# %% [markdown]
# ##### If there is a number in the question delete it

# %%
for i in range(len(df)):
  if i % 20000 == 0:
    print("Index: ", i)
  patternDigit = re.compile(r'.*\d.*')
  row = df.iloc[i]
  question = row['question']
  # try:
  if len(patternDigit.findall(question)) > 0:
    removed_questions.append(row)
  else:
    questions_left.append(row)
  # except:
  #   print("Error at index: ", str(i), ", type: ", str(type(question)), ", question: " , str(question), ", row: " +str(row))
  #   removed_questions.append(row) 

print(len(removed_questions))
print(len(questions_left))
# Out:
# Index:  0
# Index:  20000
# Index:  40000
# Index:  60000
# Index:  80000
# Index:  100000
# Index:  120000
# Index:  140000
# Index:  160000
# Index:  180000
# Index:  200000
# Index:  220000
# Index:  240000
# Index:  260000
# 116466
# 157750

# %% [markdown]
# Hence we remove 42% of the questions

# %% [markdown]
# ##### If there are more than 3 numbers concsecutively in the question delete it

# %%
# removed_questions = []
# questions_left = []

# %%
# for i in range(len(df[:100000])):
#   if i % 20000 == 0:
#     print("Index: ", i)
#   patternDigit = re.compile(r'.*\d\d\d.*')
#   row = df.iloc[i]
#   question = row['question']
#   # try:
#   if len(patternDigit.findall(question)) > 0:
#     removed_questions.append(row)
#   else:
#     questions_left.append(row)
#   # except:
#   #   print("Error at index: ", str(i), ", type: ", str(type(question)), ", question: " , str(question), ", row: " +str(row))
#   #   removed_questions.append(row) 

# print(len(removed_questions))
# print(len(questions_left))

# %%
# temp = []
# for i in range(len(df[:100000])):
#   if i % 20000 == 0:
#     print("Index: ", i)
#   patternDigit = re.compile(r'.*\d.*')
#   row = df.iloc[i]
#   question = row['question']
#   # try:
#   if len(patternDigit.findall(question)) > 0:
#     temp.append(row)
#   # except:
#   #   print("Error at index: ", str(i), ", type: ", str(type(question)), ", question: " , str(question), ", row: " +str(row))
#   #   removed_questions.append(row) 

# print(len(temp))

# %%
# pd.DataFrame(temp)

# %% [markdown]
# Hence we remove 20% of the questions

# %% [markdown]
# ##### If there is a non-ASCII charater in the question delete it
# The devanagri chars have the unicod eindexes 0900 - 097F according to [stackoverflow](https://stackoverflow.com/questions/41356013/how-to-detect-if-a-string-contains-hindi-devnagri-in-it-with-character-and-wor)

# %%
cleanDf = pd.DataFrame(questions_left)
questions_left = []

# %%
for i in range(len(cleanDf)):
  if i % 20000 == 0:
    print("Index: ", i)
  patternHindi = re.compile(r'.*[\u0900-\u097F].*') 
  row = cleanDf.iloc[i]
  question = row['question']
  
  if len(patternHindi.findall(question)) > 0:
    removed_questions.append(row)
  else:
    questions_left.append(row)
  

print(len(removed_questions))
print(len(questions_left))
# Out:
# Index:  0
# Index:  20000
# Index:  40000
# Index:  60000
# Index:  80000
# Index:  100000
# Index:  120000
# Index:  140000
# 140366
# 133850

# %% [markdown]
# ##### Replacing all element shortcuts with their full forms

# %%
cleanDf = pd.DataFrame(questions_left)
questions_left = []

# %%
zync potassium

# %%
cleanDf
# Out:
#                                                  question syllabus_id
# 7              How many π bonds are present in ferrocene       700295
# 10      What is covalency of chlorine atom in second e...      698013
# 25      In solid X atoms goes to corner of the cube an...      700078
# 28      Calculate value of x y here x and y are the to...      697895
# 40      In phosphorus acid if X is number of non bondi...      697895
# ...                                                   ...         ...
# 276441                       subjective english question           -1
# 276442                       question subjective english           -1
# 276443                      subjective english questions           -1
# 276445                                              test           -1
# 276446                           paragraph question text    (1, 2, 3)
#
# [134756 rows x 2 columns]
# Warning: total number of rows (134756) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
cleanDf[-20000:]
# Out:
#                                                  question syllabus_id
# 245116  A parallel plate condenser with dielectric of ...        4174
# 245117  The energy required to charge a parallel plate...        4174
# 245118                   To store electric charge we use         4174
# 245119                  One micro microfarad is equal to         4174
# 245120  After an isolated conducting sphere is given a...        4174
# ...                                                   ...         ...
# 276441                       subjective english question           -1
# 276442                       question subjective english           -1
# 276443                      subjective english questions           -1
# 276445                                              test           -1
# 276446                           paragraph question text    (1, 2, 3)
#
# [20000 rows x 2 columns]

# %%
len(cleanDf)
# Out:
# 134756

# %% [markdown]
# ### Saving as file

# %%
cleanDf.to_csv("drive/MyDrive/Extramarks Project/Dataset versions/JEE-with-answers-without-numericals.csv")
