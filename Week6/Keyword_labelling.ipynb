# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkteshV/Question_duplicate_detection/blob/main/Week6/Keyword_labelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import argparse
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch
import requests
import json
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
jee1 = pd.read_csv("/content/drive/MyDrive/Literature Review/Dataset versions/SSDS/Keyword Extractions(first 1k from 10k DS)/MultipartiteRank-extracted_keywords.csv", index_col = 0)
jee2 = pd.read_csv("/content/drive/MyDrive/Literature Review/Dataset versions/SSDS/Keyword Extractions(first 1k from 10k DS)/TopicalPageRank-extracted_keywords.csv", index_col = 0)
jee3 = pd.read_csv("/content/drive/MyDrive/Literature Review/Dataset versions/SSDS/Keyword Extractions(first 1k from 10k DS)/PositionRank-extracted_keywords.csv", index_col = 0)

# %%
answers = []

for i in range(30):
  print(jee1.iloc[i]['question'])
  print(jee1.iloc[i]['keywords'])
  print(jee2.iloc[i]['keywords'])
  print(jee3.iloc[i]['keywords'])

  inp = input()

  inp = inp.split()

  try:
    ls = [int(inp[0]), int(inp[1]), int(inp[2])]
    answers.append(ls)
  except: 
    print("Fail")
# Out:
# the first method used for determining the actual age of rocks was developed by
# ['actual age', 'rocks']
# ['actual age', 'first method', 'rocks']
# ['first method', 'actual age', 'rocks']
# 0 1 1
# when we subtract a number from itself we get
# ['number']
# ['number']
# ['number']
# 0 0 0
# what orbitals has two spherical nodes
# ['orbitals', 'spherical nodes']
# ['spherical nodes', 'orbitals']
# ['spherical nodes', 'orbitals']
# 1 1 1
# the reagent used to step up in the homologous series of acids is
# ['homologous series', 'acids', 'reagent']
# ['homologous series', 'reagent', 'acids']
# ['homologous series', 'reagent', 'acids']
# 1 1 1
# the shortcut key to delete a slide
# ['shortcut key', 'slide']
# ['shortcut key', 'slide']
# ['shortcut key', 'slide']
# 1 1 1
# draw the energy level diagram for the given process dissolving ammonium chloride in water
# ['ammonium chloride', 'process', 'water', 'energy level diagram']
# ...

# %% [markdown]
# Need to extract the verbs as well. But then not sure if any sense.

# %%
df = pd.DataFrame(answers, columns=['MultipartiteRank', 'TopicalPageRank', 'PositionRank'])
df.head()
# Out:
#    MultipartiteRank  TopicalPageRank  PositionRank
# 0                 0                1             1
# 1                 0                0             0
# 2                 1                1             1
# 3                 1                1             1
# 4                 1                1             1

# %%
one=df['MultipartiteRank']
two=df['TopicalPageRank']
three=df['PositionRank']

def calculate_score_given_series (ser):
  return len(ser[ser==1])/len(ser)*100

# %%
print("MultipartiteRank score: ", calculate_score_given_series(one))
print("TopicalPageRank score: ", calculate_score_given_series(two))
print("PositionRank score: ", calculate_score_given_series(three))
# Out:
# MultipartiteRank score:  50.0
# TopicalPageRank score:  66.66666666666666
# PositionRank score:  63.33333333333333
