# %% [markdown]
# # **EDA on ExtraMarks Dataset (EMD)**

# %% [markdown]
# Dataset : https://drive.google.com/file/d/1Tk8RMvZr6cnwSRIBVnnsNe7z50SWbY_9/view?usp=sharing
#
# *Key features* about the data :
#
# 1. Unlabelled Data
#
# 2. There were many columns/features in the actual dataset though we have taken only two of them, 1st being the `question text` itself and second the `syllabus id` associated with it.
#
# 3. A rough idea on how syllabus id can be useful is , creating large buckets of questions of same subjects and then we kind of reduce our search space for near duplicates.
#
# 4. Though can't be sure if syllabus id are 100% correct or not (Human errors).
#
# 5. The question text has been preprocessed. Like removing some hyperlinks from the question, removing questions having many numerical data at this point of time.
# ---
#
# ###**AIM :**
# `Getting familiar with the EM Dataset and exploring it a bit more deeply`.

# %% [markdown]
# ### **Brief Overview of the EM Dataset**
#  ---
#
# ![Metadata.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question data field**
#
# https://drive.google.com/file/d/1qOR1WOItaBvwOhihDJ4nFnqD8sgyYwr4/view?usp=sharing

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("drive/MyDrive/Extramarks Project/Dataset versions/EM-String-only-questions(cleanDf).csv")

# %%
df = df[['question','syllabus_id']]
df
# Out:
#                                                  question syllabus_id
# 0              How many π bonds are present in ferrocene       700295
# 1       What is covalency of chlorine atom in second e...      698013
# 2       In solid X atoms goes to corner of the cube an...      700078
# 3       Calculate value of x y here x and y are the to...      697895
# 4       In phosphorus acid if X is number of non bondi...      697895
# ...                                                   ...         ...
# 134751                       subjective english question           -1
# 134752                       question subjective english           -1
# 134753                      subjective english questions           -1
# 134754                                              test           -1
# 134755                           paragraph question text    (1, 2, 3)
#
# [134756 rows x 2 columns]

# %% [markdown]
# After pre-processing some questions seems incomplete.
#
# > Example :
# > - In the closest packing of atoms
# > - Incorrect order of bond angles is
#
# Possible reasons ?
#
# - Had some images with them
# - MCQ type question
#
# ⚡ For `MCQ based question` or `Image Based Ques` we need to take into the account the options/ Images given with it as well right ?
#
# > Example : Select incorrect option	is the only text and rest is in image.
#
# > Example : Find the best choice out of these options. Though there can be many answers to this prob, there is only one valid answer in options given. So now if the options change the problem remains the same or becomes diff.
#
# > - Find the oxidizing agent among the options. -> A B C H2O2 , correct is H202
# > - Find the oxidizing agent among the options. -> A B C KMno4 , correct is KMno4
#
# > Since these questions test 2 diff knowledge buckets will it be duplicates or not ?

# %%
print("Number of Questions in this pre-processed data :", df.shape[0])
print(df.shape)
# Out:
# Number of Questions in this pre-processed data : 134756
# (134756, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134756 entries, 0 to 134755
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   question     134756 non-null  object
#  1   syllabus_id  134756 non-null  object
# dtypes: object(2)
# memory usage: 2.1+ MB

# %%
df.isnull().sum()
# Out:
# question       0
# syllabus_id    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 10864

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (123892, 2)

# %% [markdown]
# ?? Should I remove duplicates or not ? Since we wan't to find word share.

# %% [markdown]
# ##### **FEATURE ENGINEERING ON THE DATASET**
#
# - Character length of a question
# - Number of words in a question

# %%
# Character length of a question

df["len"] = df["question"].str.len()-1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Number of words
df["words"] = df["question"].str.strip().str.split().str.len()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Number of common words

def to_lower(d):
  a = [[x.lower() for x in s] for s in d]
  return a 

def common_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return len(w1 & w2)

def total_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return (len(w1|w2))

# %%
# Question lengths statistics

sns.displot(df['len'])
print('Minimum characters',df['len'].min())
print('Maximum characters',df['len'].max())
print('Average number of characters',int(df['len'].mean()))
# Out:
# Minimum characters 1
# Maximum characters 4919
# Average number of characters 85

# %%
# Questions with len = 1,2,3 Are they of any use ?

df.loc[df['len'] == 4]
# Out:
#        question syllabus_id  len  words
# 4385      null       734178    4      1
# 4387      null       734444    4      1
# 4394      null       734172    4      1
# 8455      null       734330    4      1
# 11587     null       698314    4      1
# 11791     null       734241    4      1
# 20325     null       448430    4      1
# 20791     They       511225    4      1
# 22453     Dove       511224    4      1
# 22768     They       511224    4      1
# 61816     test          445    4      1
# 73638     John       509609    4      1
# 77386     test        22010    4      1
# 89953     went        85585    4      1
# 93617     C is         5112    4      2
# 124956    This         4767    4      1
# 125359    They         4766    4      1
# 125360    Dove         4766    4      1
# 125970    Base         4655    4      1
# 126061    Base         4487    4      1
# 134602    test           -1    4      1
# 134614    TEST           -1    4      1
# 134634    dasd           -1    4      1
# 134637    fgdf           -1    4      1
# 134638    sdsa           -1    4      1
# 134744    kjkj           -1    4      1

# %%
sns.displot(df['words'])
print('Minimum words',df['words'].min())
print('Maximum words',df['words'].max())
print('Average num of words',int(df['words'].mean()))
# Out:
# Minimum words 1
# Maximum words 1017
# Average num of words 15

# %%
# Questions with words = 1,2,3 Are they of any use, seems useful ?

df.loc[df['words'] >= 1000]
# Out:
#                                                 question syllabus_id   len  \
# 90071  p strong Read the given story and answer the q...       86253  4919
#
#        words
# 90071   1017

# %%
from collections import OrderedDict
import operator
import nltk
from nltk import bigrams, trigrams, word_tokenize
from collections import Counter, defaultdict
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
ques = df['question'].tolist()

for i in range(len(ques)):
    ques[i] = ques[i].lower()

ques = list(set(ques))

# sz = 10000
# ques

len(ques)
# Out:
# 113893

# %%
unigrams = []

for sent in ques :
  unigrams.append(set(nltk.word_tokenize(sent)))

# unigrams

# %%
req_pairs = []
threshold = 0.8

sz = 30000

for i in range(0,sz-1):

  print(i)

  s1 = unigrams[i]

  for j in range(i+1,sz):

    s2 = unigrams[j]

    union = len(s1|s2)
    common = len(s1&s2)

    jaccard_sim =  common/union

    if(jaccard_sim >= threshold):
      req_pairs.append([ques[i],ques[j]])

# %%
req_pairs
# Out:
# [['t h e s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d x e x cos x x tan x i s ',
#   't h e s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d x a e b x c cos m x i s '],
#  ['t h e s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d x e x cos x x tan x i s ',
#   't h e s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d x s e c x s e c x t a n x i s '],
#  ['t h e s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d x e x cos x x tan x i s ',
#   't h e g e n e r a l s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n l o g d y d x x y i s '],
#  ['t h e s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d x e x cos x x tan x i s ',
#   't h e d i f f e r e n t i a l e q u a t i o n y d y d x x a a i s a n y c o n s t a n t r e p r e s e n t s '],
#  ['t h e s o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d x e x cos x x tan x i s ',
#   's o l u t i o n o f t h e d i f f e r e n t i a l e q u a t i o n d y d
s '],
#  ['i f t h e v e c t o r s a a n d b a r e m u t u a l l y p e r p e n d i c u l a r t h e n a a a b i s e q u a l t o ',
#   't h e d i f f e r e n t i a l e q u a t i o n o f t h e f a m i l y o f c u r v e s v a r b w h e r e a a n d b a r e a r b i t r a r y c o n s t a n t s i s '],
#  ['i f t h e v e c t o r s a a n d b a r e m u t u a l l y p e r p e n d i c u l a r t h e n a a a b i s e q u a l t o ',
#   'c o n s i d e r a g a s w i t h d e n s i t y ρ a n d c a s t h e r o o t m e a n s q u a r e v e l o c i t y o f i t s m o l e c u l e s c o n t a i n e d i n a v o l u m e i f t h e s y s t e m m o v e s a s w h o l e w i t h v e l o c i t y v t h e n t h e p r e s s u r e e x e r t e d b y t h e g a s i s '],
#  ['i f t h e v e c t o r s a a n d b a r e m u t u a l l y p e r p e n d i c u l a r t h e n a a a b i s e q u a l t o ',
#   'i f u v a n d w a r e t h r e e n o n c o p l a n a r v e c t o r s t h e n u v w u v v w e q u a l s '],
#  ['i f t h e v e c t o r s a a n d b a r e m u t u a l l y p e r p e n d i c u l a r t h e n a a a b i s e q u a l t o ',
#   't h e n u m b e r o f p o s s i b l e i n t e g r a l v a l u e s o f b c w h e r e a b c a r e s i d e s o f a t r i a n g l e a n d a r e i n a p '],
#  ['i f t h e v e c t o r s a a n d b a r e m u t u a l l y p e r p e n d i c u l a r t h e n a a a b i s e q u a l t o ',
#   'i f t h e n o n z e r o v e c t o r s a a n d b a r e p e r p e n d i c u l a r t o e a c h o t h e r t h e n t h e s o l u t i o n o f t h e e q u t i o n r a b i s '],
#  ['i f t h e v e c t o r s a a n d b a r e m u t u a l l y p e r p e n d i c u l a r t h e n a a a b i s e q u a l t o ',
#   'w h i c h o f t h e f o l l o w i n g p i e c e s o f d a t a d o e s n o t u n i q u e l y d e t e r m i n e a c u t e a n g l e d δ a b c r c i r c u m r a d i u s '],
#  ['i f t h e v e c t o r s a a n d b a r e m u t u a l l y p e r p e n d i c u l a r t h e n a a a b i s e q u a l t o ',
#   'l e t t r u t h v a l u e s o f p b e f a n d q b e t t h e n t r u t h v a l u e o f p q i s '],
#  ['a pipe open at both ends has a fundamental frequency f in air the pipe is dipped vertically in water so that half of it is in water the fundamental frequency of the air column is now ',
#   'a pipe open at both ends has a fundamental frequency f in air the pipe is dipped vertically in water so that half of it is in water the fundamental frequencty of the air column is now '],
#  ['which one of the following statements is true ',
#   'which of the following statements is true '],
#  ['name of the segment of dna which acts as the instruction manual for the synthesis of the protein is ',
#   'the segment of dna which acts as the instrumental manual for the synthesis of the protein is '],
#  ['the header file to which the function clrscr belongs to is ',
#   'the header file to which the function gets belongs to is '],
#  ['the curve that lies below the line of equal distribution line is called ____________ ',
#   'the curve that lies below the line of equal distribution line is called '],
#  ['match list i with list ii and select the correct answer using the codes given below list i list ii a cyanide process i ultrapure ge b floatation process ii pine oil c electrolytic reduction iii extraction of al d zone refining iv extraction of au ',
#   'match list i with list ii and select the correct answer using the codes given below the lists list i list ii i cyanide process a ultrapure ge ii floatation process b pine oil iii electrolytic reduction c extraction of al iv zone refining d extraction of au '],
#  ['out of the following the correct statement is ',
#   'out of the following statements the correct statement is '],
#  ['a topology in which each node relays data for the network ',
#   'topology in which each node relays data for the network '],
#  ['ph scale is used for determining the ',
#   'ph scale is used for determining '],
#  ['the statement p q p p p q is ', 'the statement q p q p p is '],
#  ['the statement p q p p p q is ', 'the following statement p q p q q is '],
#  ['which of the following transaction is a revenue receipt ',
#   'which of the following is not a revenue receipt '],
#  ['the arithmetic mean of the squares of first n natural numbers is ',
#   'the arithmetic mean of first n odd natural numbers is '],
#  ['how many letter u are there in the word unusual ',
#   'how many letter u are there in the word unique '],
#  ['how many letter u are there in the word unusual ',
#   'how many letter u are there in the word dumdum '],
#  ['identify the structure of the sentence by selecting simple or compound paul played well and i decided to do better a simple b compound ',
#   'identify the structure of the sentence by selecting simple or compound paul play well and i decided to do better a simple b compound '],
#  ['how many letter f are there in the word cuff ',
#   'how many letter f are there in the word flyoff '],
#  ['how many letter f are there in the word cuff ',
#   'how many letter f are there in the word off '],
#  ['how many letter f are there in the word cuff ',
#   'how many letter f are there in the word africa '],
#  ['how many letter f are there in the word cuff ',
#   'how many letter f are there in the word life '],
#  ['which of the words given below can be placed after time to form a compound word ',
#   'which of the words given below can be placed after every to form a compound word '],
#  ['which of the words given below can be placed after time to form a compound word ',
#   'which of the words given below can be placed after child to form a compound word '],
#  ['define the term non renewable sources of energy ',
#   'define the term renewable sources of energy '],
#  ['which of the following is an antonym of the word equanimity ',
#   'which of the following is an antonym of the word voracious '],
#  ['which of the following is an antonym of the word equanimity ',
#   'which of the following is an antonym of the word bellicose '],
#  ['which one of the following functions is not a self inverse function ',
#   'which one of the following functions is a self inverse function '],
#  ['how many letter g are there in the word googly ',
#   'how many letter g are there in the word goggle '],
#  ['how many letter g are there in the word googly ',
#   'how many letter g are there in the word grandaughter '],
#  ['i asked her not to call me but she ',
#   'i asked her not to talk to me but she '],
#  ['a student tested a sample of distill water with the blue and red litmus papers choose the correct observation for his experiment ',
#   'a student tested a sample of distilled water with the blue and red litmus papers choose the correct observation for his experiment '],
#  ['toluene reacts with a halogen in the presence of iron iii chloride giving ortho and para halo compounds the reaction is ',
#   'toulene reacts with a halogen in the presence of iron chloride giving ortho and para halo compounds the reaction is '],
#  ['the shortcut key which is used to paste the selected text ',
#   'the shortcut key that is used to paste the selected text '],
#  ['the shortcut key which is used to paste the selected text ',
#   'which shortcut key is used to paste the selected text '],
#  ['i f y x sin x f i n d d y d x ', 'y x f i n d d y d x '],
#  ['i f y x sin x f i n d d y d x ', 'i f y sin x e x f i n d d y d x '],
#  ['the superlative form of fancy is ___________________ ',
#   'the superlative form of fancy is '],
#  ['blue colour of the sky is due to scattering of ',
#   'blue colour of the sky is due to '],
#  ['the differential equation representing the family of parabolas having vertex at origin and axis along positive direction of _x_ axis is ',
#   'form the differential equation representing the family of parabolas having vertex at origin and axis along positive direction of _x_ axis '],
#  ['nacl shows schottky defects and agcl frenkel defects their electrical conductivity is due to the ',
#   'nacl shows schottky defects and agcl frenkel defects their electrical conductivity is due to '],
#  ['which of the following processes is not a part of water cycle ',
#   'which of the following is not the part of water cycle '],
#  ['what can we measure by the help of porometer ',
#   'what can we measure by the help of potometer '],
#  ['the orbital diagram in which both the pauli s exclusion principle and hund s rule violated is ',
#   'the orbital diagram in which both the pauli s exclusion principle and hund s rule are violated is '],
#  ['the orbital diagram in which both the pauli s exclusion principle and hund s rule violated is ',
#   "the orbital diagram in which both the pauli's exclusion principle and hund's rule are violated is "],
#  ['the angular momentum of an electron in a hydrogen atom is proportional to ',
#   'an electron revolves around the nucleus of a hydrogen atom angular momentum of an electron in a hydrogen atom is proportional to '],
#  ['which one of the following is correct ',
#   'which one of the following statements is correct '],
#  ['which one of the following is correct ',
#   'which one of the following is the correct statement '],
#  ['which one of the following is correct ',
#   'which one of the following options is correct '],
#  ['the number that is a factor of every number is_______________ ',
#   'the number that is a factor of every number is '],
#  ['which pair of elements can from multiple bond with itself and oxygen ',
#   'which pair of elements can form multiple bond with itself and oxygen '],
#  ['the change in optical rotation of freshly prepared solution of sugar with time is known as ',
#   'the change in optical rotation with time of a freshly prepared solution of sugar is known as '],
#  ['the language that is used to create web pages ',
#   'name the language that is used to create web pages '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'i f a b c a r e t h r e e n o n c o p l a n a r v e c t o r s t h e n a b c a c a b i s e q u a l t o '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'a b c d i s a q u a d r i l l a t e r a l f o r c e b a b c c d a n d d a a c t a t t h e p o i n t t h e i r r e s u l t a n t i s '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'i f p q a n d r a r e s u b s e t s o f a s e t a t h e n r p c q c c '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'i n t h e s t u d y o f t r a n s i s t o r a s a m p l i f i e r i f α i c i e a n d β i c i b w h e r e i c i b a n d i e a r e t h e c o l l e c t o r b a s e a n d e m i t t e r c u r r e n t s t h e n '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'a c o u p l e i s o f m o m e n t g a n d t h e f o r c e f o r m i n g t h e c o u p l e i s p i f p i s t u r n e d t h r o u g h a r i g h t a n g l e t h e m o m e n t o f t h e c o u p l e t h u s f o r m e d i s h i f i n s t e a d t h e f o r c e p a r e t u r n e d t h r o u g h a n a n g l e α t h e n t h e m o m e n t o f c o u p l e b e c o m e s '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'i f a c i r c l e i s i n s c r i b e d i n a n e q u i l a t e r a l t r i a n g l e o f s i d e a t h e n a r e a o f t h e s q u a r e i n s c r i b e d i n t h e c i r c l e i s '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'i f t h e n o n z e r o v e c t o r s a a n d b a r e p e r p e n d i c u l a r t o e a c h o t h e r t h e n t h e s o l u t i o n o f t h e e q u t i o n r a b i s '],
#  ['i f a b c α d b c d β a t h e n a b c d i s e q u a l t o a b c a r e n o n c o p l a n a r ',
#   'l e t t r u t h v a l u e s o f p b e f a n d q b e t t h e n t r u t h v a l u e o f p q i s '],
#  ['ben a trader wishes to know the cost of goods sold during the year which financial statement will provide the amount of cogs ',
#   'john is a trader wishes to know the cost of goods sold during the year which financial statement will provide the amount of cogs '],
#  ['at the time of preparing balance sheet loss is shown under ',
#   'at the time of preparing balance sheet loss is shown under the head '],
#  ['father of the computer ', 'the father of computer '],
#  ['where was the conference of peace held after the world war i ',
#   'the conference of peace after the world war i was held in '],
#  ['write two examples each of sexually transmitted diseases caused by i virus ii bacteria explain how the transmission of such diseases be prevented ',
#   'write two examples each of sexually transmitted diseases caused by i virus ii bacteria explain how the transmission of such diseases can be prevented '],
#  ['the ____________ displays the thumbnails of all the sprites in a project ',
#   'the area displays the thumbnails of all the sprites in a project '],
#  ['dinitrogen and dioxygen are main constituents of air but these do not react with each other to form oxides of nitrogen because ',
#   'dinitrogen and dioxygen are main constituents of air but these do not react with each other to form oxides of nitrogen because _ '],
#  ['which of the following can possibly be used as analgesic without causing addiction and modification ',
#   'which one of the following can possibly be used as analgesic without causing addiction and mood modification '],
#  ['in the passage given below one word has been omitted in each line write the missing word along with the word that comes before and the word that comes after it against the correct blank number ensure that the word that forms your answer is underlined one morning a farmer was astonished discover i _____ ______ _____ that his goose had laid egg of solid gold ii ____ ____ ____ he seized the precious egg ran into house iii ____ ____ ____ and with trembling hands showed it his wife iv ____ ____ ____ look my wife he said we rich then v ____ ____ ____ the farmer took the golden egg to market vi ____ ____ ____ and sold it for a good price the morning the vii ____ ____ ____ goose again laid a golden egg and farmer sold viii ____ ____ ____ that too for much money everyday thereafter found ix ____ ____ ____ in the barnyard egg of purest gold x _____ _____ _____ ',
#   'in the passage given below one word has been omitted in each line write the missing word along with the word that comes before and the word that comes after it against the correct blank number ensure that the word that forms your answer is underlined one morning a farmer was astonished discover i ______ _____ _______ that his goose had laid egg of solid gold ii ____ ____ ____ he seized the precious egg ran into house iii ____ ____ ____ and with trembling hands showed it his wife iv ____ ____ ____ look my wife he said we rich then v ____ ____ ____ the farmer took the golden egg to market vi ____ ____ ____ and sold it for a good price the morning the vii ____ ____ ____ goose again laid a golden egg and farmer sold viii ____ ____ ____ that too for much money everyday thereafter found ix ____ ____ ____ in the barnyard egg of purest gold x _____ _____ ____ '],
#  ['in which process the temperature of the system decreases ',
#   'the temperature of the system decreases in the process of '],
#  ['write a structure specification that includes four float type variables length height width and volume call it box ',
#   'write a structure specification that includes four float type variables length height width and volume call it a box '],
#  ['the monthly total of the purchase book is ',
#   'the monthly total of the purchase return book is '],
#  ['you have potato carrot radish sweet potato tomato and ginger bought from the market in your jute bag identify two vegetables to represents the correct homologous structures a potato and tomato b carrot and tomato c potato and sweet potato d carrot and radish ',
#   'you have potato carrot radish sweet potato tomato and ginger bought from the market in your jute bag identify two vegetables to represent the correct homologous structures a potato and tomato b carrot and tomato c potato and sweet potato d carrot and radish '],
#  ['select the word which is synonymous in meaning to the word abstemious ',
#   'select the word which is synonymous in meaning to the word anomalous '],
#  ['select the word which is synonymous in meaning to the word abstemious ',
#   'select the word which is synonymous in meaning to the word laudable '],
#  ['select the word which is synonymous in meaning to the word abstemious ',
#   'select the word which is synonymous in meaning to the word plethora '],
#  ['the reactivity order of halides for dehydrohalogenation is ',
#   'reactivity order of halides for dehydrohalogenation is '],
#  ['a b c a r e n o n e m p t y s e t s t h e n t h e v a l u e o f a b b c c a i s ',
#   'a v e c t o r a p o i n t s v e r t i c a l l y u p w a r d a n d b p o i n t s t o w a r d s n o r t h t h e v e c t o r p r o d u c t a b i s '],
#  ['a b c a r e n o n e m p t y s e t s t h e n t h e v a l u e o f a b b c c a i s ',
#   't h e n u m b e r o f c r i t i c a l p o i n t s o f t h e f u n c t i o n f x x e x m u s t b e '],
#  ['a b c a r e n o n e m p t y s e t s t h e n t h e v a l u e o f a b b c c a i s ',
# ...
#   't h e d e c i m a l p a r t s o f t h e l o g a r i t h m s o f t w o n u m b e r s t a k e n a t r a n d o m a r e f o u n d t o s i x p l a c e s p r o b a b i l i t y t h a t s e c o n d c a n b e s u b t r a c t e d f r o m o n e f i r s t w i t h o u t b o r r o w i n g i s '],
#  ['a c h a r g e d p a r t i c l e w i t h c h a r g e q e n t e r s r e g i o n o f c o n s t a n t u n i f o r m a n d m u t u a l l y o r t h o g o n a l f i e l d e a n d b a n d c o m e s o u t w i t h o u t a n y c h a n g e i n m a g n i t u d e o r d i r e c t i o n o f υ t h e n ',
#   'a r i n g o f r a d i u s r h a s c h a r g e q d i s t r i b u t e d u n i f o r m l y o v e r i t t h e c h a r g e t h a t s h o u l d p l a c e d a t t h e c e n t r e o f t h e r i n g s u c h t h a t t h e e l e c t r i c f i e l d b e c o m e s z e r o a t a p o i n t o n t h e a x i s o f t h e r i n g d i s t a n c e r f r o m t h e c e n t r e o f t h e r i n g i s q p q f i n d t h e v a l u e o f p q '],
#  ['a c h a r g e d p a r t i c l e w i t h c h a r g e q e n t e r s r e g i o n o f c o n s t a n t u n i f o r m a n d m u t u a l l y o r t h o g o n a l f i e l d e a n d b a n d c o m e s o u t w i t h o u t a n y c h a n g e i n m a g n i t u d e o r d i r e c t i o n o f υ t h e n ',
#   'i f p q r b e t h r e e m u t u a l l y p e r p e n d i c u l a r v e c t o r s o f e q u a l m a g n i t u d e t h e n t h e a n g l e b e t w e e n p a n d p q r i s '],
#  ['a c h a r g e d p a r t i c l e w i t h c h a r g e q e n t e r s r e g i o n o f c o n s t a n t u n i f o r m a n d m u t u a l l y o r t h o g o n a l f i e l d e a n d b a n d c o m e s o u t w i t h o u t a n y c h a n g e i n m a g n i t u d e o r d i r e c t i o n o f υ t h e n ',
#   't h e d i f f e r e n t i a l e q u a t i o n o f t h e f a m i l y o f c u r v e s v a r b w h e r e a a n d b a r e a r b i t r a r y c o n s t a n t s i s '],
#  ['a c h a r g e d p a r t i c l e w i t h c h a r g e q e n t e r s r e g i o n o f c o n s t a n t u n i f o r m a n d m u t u a l l y o r t h o g o n a l f i e l d e a n d b a n d c o m e s o u t w i t h o u t a n y c h a n g e i n m a g n i t u d e o r d i r e c t i o n o f υ t h e n ',
#   'c o n s i d e r a g a s w i t h d e n s i t y ρ a n d c a s t h e r o o t m e a n s q u a r e v e l o c i t y o f i t s m o l e c u l e s c o n t a i n e d i n a v o l u m e i f t h e s y s t e m m o v e s a s w h o l e w i t h v e l o c i t y v t h e n t h e p r e s s u r e e x e r t e d b y t h e g a s i s '],
#  ['a c h a r g e d p a r t i c l e w i t h c h a r g e q e n t e r s r e g i o n o f c o n s t a n t u n i f o r m a n d m u t u a l l y o r t h o g o n a l f i e l d e a n d b a n d c o m e s o u t w i t h o u t a n y c h a n g e i n m a g n i t u d e o r d i r e c t i o n o f υ t h e n ',
#   't h e n u m b e r o f p o s s i b l e i n t e g r a l v a l u e s o f b c w h e r e a b c a r e s i d e s o f a t r i a n g l e a n d a r e i n a p '],
#  ['a c h a r g e d p a r t i c l e w i t h c h a r g e q e n t e r s r e g i o n o f c o n s t a n t u n i f o r m a n d m u t u a l l y o r t h o g o n a l f i e l d e a n d b a n d c o m e s o u t w i t h o u t a n y c h a n g e i n m a g n i t u d e o r d i r e c t i o n o f υ t h e n ',
#   'w h i c h o f t h e f o l l o w i n g p i e c e s o f d a t a d o e s n o t u n i q u e l y d e t e r m i n e a c u t e a n g l e d δ a b c r c i r c u m r a d i u s '],
#  ['which of the following is a metalloid ',
#   'which of the following is metalloid '],
#  ['kofi annan created the to fight aids and tuberculosis ',
#   'kofi annan created the global fund to fight aids tuberculosis and '],
#  ['out of the two given statements one is assertion and other is reason read them and try to identify the correlation between the two statements assertion mutation in a gamete may results in a genetic disorder reason if mutation occurs in a gamete it will affect all the cells of the individual that develop from that zygote a both assertion and reason are true and reason is the correct explanation of the assertion b both assertion and reason are true and reason is not the correct explanation of the assertion c both assertion and reason are false d assertion is true but reason is false ',
#   'out of the two given statements one is _assertion_ and other is _reason_ read them and try to identify the correlation between the two statements assertion mutation in a gamete may result in a genetic disorder reason if mutation occurs in a gamete it will affect all the cells of the individual that develop from that zygote a both _assertion_ and _reason_ are true and reason is the correct explanation of the assertion b both _assertion_ and _reason_ are true and reason is not the correct explanation of the assertion c both _assertion_ and _reason_ are false d _assertion_ is true but _reason_ is false '],
#  ['the ratio of root mean square velocity to average velocity of gas molecules at a particular temperature is ',
#   'the ratio of root mean square velocity to average velocity of a gas molecule at a particular temperature is '],
#  ['select the word which is an antonym of the word intrepid ',
#   'select the word which is an antonym of exacerbate '],
#  ['which among the following neither have a fixed shape nor a fixed volume ',
#   'which among the following has neither a fixed shape nor a fixed volume '],
#  ['i n a δ a b c t h e v a l u e o f a cos a b cos b c cos c a b c i s e q u a l t o ',
#   'i n a δ a b c a b cos c c cos b i s e q u a l t o '],
#  ['the shortcut key which is used to create a chart instantly ',
#   'what is the shortcut key used to create a chart instantly '],
#  ['which of the following is not an example of ionic compound ',
#   'which of the following is not an example of coordinate compound '],
#  ['the statement that is used to generate musical notes ',
#   'name the statement that is used to generate musical notes '],
#  ["newton's second law gives the measure of ",
#   "newton 's second law gives the measure of "],
#  ['which one of the following reactions is an example of calcination process ',
#   'which one of the following reactions is an example for calcination process '],
#  ['barely often etc are examples of ',
#   'barely often etc are examples of ____________ '],
#  ['most acidic compound among the following is ',
#   'among the following the most acidic is '],
#  ['when the value of assets decreases the account to be debited is ',
#   'when the value of assets increases the account to be debited is '],
#  ['which of the following is the strongest bronsted acid ',
#   'which of the following is strongest acid '],
#  ['among the following the most acidic is ',
#   'most acidic oxide among the following is '],
#  ['which of the following is not a synonym of stay ',
#   'which of the following is not a synonym of humiliation '],
#  ['choose the correct passive voice sentence i had experienced a lot of difficulty ',
#   'i had experienced a lot of difficulty the correct passive voice of the sentence is '],
#  ['which unit of measurement would you use to measure the distance between two states ',
#   'which unit of measurement would you use to measure the distance between two districts '],
#  ['which of the following instruments is used to measure atmospheric moisture ',
#   'which of the following instruments is used to measure atmospheric pressure '],
#  ['which of the following words is an adjective of number ',
#   'which of the following words is an adjective of quality '],
#  ['which of the following words is an adjective of number ',
#   'which of the following words is an interrogative adjective '],
#  ['what does a linear equation in two variables represent ',
#   'what does a linear equation in three variables represent '],
#  ["if a solid has a structure in which w' atoms are located at the corners of a cubic lattice o' atoms at the centre of edges and na atoms at the centre of the cube what is the formula of the compound ",
#   "what is the formula of the compound as the solid has a structure in which 'w' atoms are located at the corners of a cubic lattice 'o' atom at the centre of the edges and 'na' atom at centre of the cubic "],
#  ['which of the following is not an extinct animal ',
#   'which of the following is not an aerial animal '],
#  ['which of the following is not an extinct animal ',
#   'which of the following is not an endangered animal '],
#  ['a p a r t i c l e o f p o s i t i v e c h a r g e q a n d m a s s m e n t e r s w i t h v e l o c i t y v j a t t h e o r i g i n i n a m a g n e t i c f i e l d b k w h i c h i s p r e s e n t i n t h e w h o l e s p a c e t h e c h a r g e m a k e s a p e r f e c t l y i n e l a s t i c c o l l i s i o n w i t h i d e n t i c a l p a r t i c l e a t r e s t b u t f r e e t o m o v e a t i t s m a x i m u m y c o o r d i n a t e a f t e r c o l l i s i o n t h e c o m b i n e d c h a r g e w i l l m o v e o n t r a j e c t o r y w h e r e r m v q b ',
#   'i f t w o n o n p a r a l l e l v e c t o r s a a n d b a r e e q u a l i n m a g n i t u d e t h e n t h e v e c t o r s a b a n d a b w i l l b e '],
#  ['a p a r t i c l e o f p o s i t i v e c h a r g e q a n d m a s s m e n t e r s w i t h v e l o c i t y v j a t t h e o r i g i n i n a m a g n e t i c f i e l d b k w h i c h i s p r e s e n t i n t h e w h o l e s p a c e t h e c h a r g e m a k e s a p e r f e c t l y i n e l a s t i c c o l l i s i o n w i t h i d e n t i c a l p a r t i c l e a t r e s t b u t f r e e t o m o v e a t i t s m a x i m u m y c o o r d i n a t e a f t e r c o l l i s i o n t h e c o m b i n e d c h a r g e w i l l m o v e o n t r a j e c t o r y w h e r e r m v q b ',
#   't w o p a r t i c l e s s t a r t s i m u l t a n e o u s l y f r o m t h e s a m e p o i n t a n d m o v e a l o n g t w o s t r a i g h t l i n e s o n e w i t h u n i f o r m v e l o c i t y u a n d t h e o t h e r f r o m r e s t w i t h u n i f o r m a c c e l e r a t i o n f l e t α b e t h e a n g l e b e t w e e n t h e i r d i r e c t i o n s o f m o t i o n t h e r e l a t i v e v e l o c i t y o f t h e s e c o n d p a r t i c l e w r t t h e f i r s t i s l e a s t a f t e r a t i m e '],
#  ['a p a r t i c l e o f p o s i t i v e c h a r g e q a n d m a s s m e n t e r s w i t h v e l o c i t y v j a t t h e o r i g i n i n a m a g n e t i c f i e l d b k w h i c h i s p r e s e n t i n t h e w h o l e s p a c e t h e c h a r g e m a k e s a p e r f e c t l y i n e l a s t i c c o l l i s i o n w i t h i d e n t i c a l p a r t i c l e a t r e s t b u t f r e e t o m o v e a t i t s m a x i m u m y c o o r d i n a t e a f t e r c o l l i s i o n t h e c o m b i n e d c h a r g e w i l l m o v e o n t r a j e c t o r y w h e r e r m v q b ',
#   'i f t w o f o r c e s a c t i n g a t a p o i n t a r e r e p r e s e n t e d b y n o p a n d m o q a n d t h e i r r e s u l t a n t i s r e p r e s e n t e d b y m n o r t h e n r i s a p o i n t s u c h t h a t '],
#  ['a p a r t i c l e o f p o s i t i v e c h a r g e q a n d m a s s m e n t e r s w i t h v e l o c i t y v j a t t h e o r i g i n i n a m a g n e t i c f i e l d b k w h i c h i s p r e s e n t i n t h e w h o l e s p a c e t h e c h a r g e m a k e s a p e r f e c t l y i n e l a s t i c c o l l i s i o n w i t h i d e n t i c a l p a r t i c l e a t r e s t b u t f r e e t o m o v e a t i t s m a x i m u m y c o o r d i n a t e a f t e r c o l l i s i o n t h e c o m b i n e d c h a r g e w i l l m o v e o n t r a j e c t o r y w h e r e r m v q b ',
#   't h e d e c i m a l p a r t s o f t h e l o g a r i t h m s o f t w o n u m b e r s t a k e n a t r a n d o m a r e f o u n d t o s i x p l a c e s p r o b a b i l i t y t h a t s e c o n d c a n b e s u b t r a c t e d f r o m o n e f i r s t w i t h o u t b o r r o w i n g i s '],
#  ['a p a r t i c l e o f p o s i t i v e c h a r g e q a n d m a s s m e n t e r s w i t h v e l o c i t y v j a t t h e o r i g i n i n a m a g n e t i c f i e l d b k w h i c h i s p r e s e n t i n t h e w h o l e s p a c e t h e c h a r g e m a k e s a p e r f e c t l y i n e l a s t i c c o l l i s i o n w i t h i d e n t i c a l p a r t i c l e a t r e s t b u t f r e e t o m o v e a t i t s m a x i m u m y c o o r d i n a t e a f t e r c o l l i s i o n t h e c o m b i n e d c h a r g e w i l l m o v e o n t r a j e c t o r y w h e r e r m v q b ',
#
# 1302  in which sentence is the word there used corre...
# 1303  read the passage given below and complete the ...
# 1304  l e t t r u t h v a l u e s o f p b e f a n d ...
# 1305  which of the following statement is correct re...
#
# [1306 rows x 2 columns]

# %%
duplicate_pairs.to_csv('drive/MyDrive/Extramarks Project/Dataset versions/EMD_Dup_Pairs.csv')

# %% [markdown]
# ### **Word share / Jaccard Similarity Plot**

# %%
sns.distplot(df[df['is_duplicate'] == 0]['word_share'],label='non duplicate')
sns.distplot(df[df['is_duplicate'] == 1]['word_share'],label='duplicate')
plt.legend()
plt.show()

# %% [markdown]
# ## **Some data eyeballing to the cases where `word share is high` but still they are `not duplicates`.**
#
# - **Note** : `Word_share = Jaccard Similarity (JC)`
#
# - Number of shared terms over the number of all unique terms in both strings

# %%
vis_df = df.loc[(df['word_share'] == 1) & (df['is_duplicate']==0)]
vis_df[['question1','question2','word_share','is_duplicate']]

# %% [markdown]
# ⚡ Though questions have `Exact same (JC = 1)` vocabulary but `ordering` changes the meaning completely. This is where sementic nature is required to identify duplicates better.
#
# > Example :
# > - a) What kind of Asian guys do White girls like ?
# > - b) What kind of Asian girls do White guys like ?
#
# > Though some labels I feel are not appropriate and they should be duplicate indeed.
# > - a) Which laptop I should buy ?
# > - b) Which laptop should I buy ?

# %%
vis_df = df.loc[(df['word_share'] >= 0.9) & (df['is_duplicate']==0)]
vis_df[['question1','question2','word_share','is_duplicate']]

# Use inetractive table and sort acc to word_share values to see 0.9 word_share values first

# %% [markdown]
# ⚡ Though questions have `High word_share(JC)` vocabulary but a change of `Keyword` in the question changes it meaning.
#
# > Example : Negation sentences
# > - a) Who are the best science reporters not writing in English ?
# > - b) Who are the best science reporters writing in English ?
#
# > Example : Key noun is different
# > - a) How does a typical day in IIM C pass by ?
# > - b) How does a typical day in IIM A pass by ?
#
# > Example : More specification gets added
# > - a) How much does it cost to study in Canada ?
# > - b) How much does it cost to study medicine in Canada ?

# %%
# Some more cases where data is lexically similar but not duplicates

vis_df = df.loc[(df['word_share'] >= 0.75) & (df['is_duplicate']==0)]
vis_df[['question1','question2','word_share','is_duplicate']]

# %% [markdown]
# ⚡ Though questions have `Moderately high word_share(JC)` but a change of `Keyword` in the question changes it meaning.
#
# - **Observation** - In this chart we see short sentences whereas earlier there were long sentences, that's because changing a single word in small sentences drops down the Jaccard similarity more (Obvious though).

# %%
# More non-duplicate pairs visualization

threshold = 0.4
df.loc[(df['word_share'] >= threshold)][:200]

# %% [markdown]
# ## **Some data eyeballing to the cases where `word share is low` but still they are `duplicates`.**

# %%
vis_df = df.loc[(df['word_share'] <= 0.8) & (df['is_duplicate']==1)]
vis_df[['question1','question2','word_share','is_duplicate']][:1000]

# %% [markdown]
# What inference can we make from above ?

# %%
# def Unigram_distance(dataset):

#   model = defaultdict(lambda : 0)
#   total_count = 0 
#   for sentence in dataset:
#     sentence = nltk.word_tokenize(sentence)
#     for w1 in sentence:
#       model[w1] += 1
#       total_count += 1 ;

#   for w1 in model:
#       model[w1] /= total_count
  
#   return model

# %%
profile = ProfileReport(df, title="Quora", html={'style':{'full_width':True}})

# %%
profile.to_notebook_iframe()

# %%
# Preprocessing - ? se pehle space daaldo or remove it

# %%
drive.flush_and_unmount()
